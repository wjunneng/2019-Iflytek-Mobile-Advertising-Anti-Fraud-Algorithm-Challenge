# %%
import pandas as pd

# 项目路径
project_path = '/home/wjunneng/Python/2019-Iflytek-Mobile-Advertising-Anti-Fraud-Algorithm-Challenge'
# round1_iflyad_anticheat_testdata_feature.txt文件路径
testdata_feature_path = project_path + '/data/original/round1_iflyad_anticheat_testdata_feature.txt'
# round1_iflyad_anticheat_traindata.txt文件路径
traindata_path = project_path + '/data/original/round1_iflyad_anticheat_traindata.txt'

def get_testdata_feature(**params):
    """
    返回 testdata_feature 文件内容
    :param params:
    :return:
    """
    testdata_feature_data = pd.read_table(testdata_feature_path, sep='\t')

    return testdata_feature_data


def get_traindata(**params):
    """
    返回 traindata 文件内容
    :param params:
    :return:
    """
    traindata_data = pd.read_table(traindata_path, sep='\t')

    return traindata_data


testdata_feature = get_testdata_feature()
traindata = get_traindata()
traindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 29 columns):
# sid             1000000 non-null object
# label           1000000 non-null int64
# pkgname         1000000 non-null object
# ver             678176 non-null object
# adunitshowid    1000000 non-null object
# mediashowid     1000000 non-null object
# apptype         1000000 non-null float64
# nginxtime       1000000 non-null float64
# ip              1000000 non-null object
# city            984807 non-null object
# province        1000000 non-null float64
# reqrealip       1000000 non-null object
# adidmd5         1000000 non-null object
# imeimd5         1000000 non-null object
# idfamd5         1000000 non-null object
# openudidmd5     1000000 non-null object
# macmd5          1000000 non-null object
# dvctype         1000000 non-null float64
# model           995533 non-null object
# make            876161 non-null object
# ntt             1000000 non-null float64
# carrier         1000000 non-null float64
# os              1000000 non-null object
# osv             987003 non-null object
# orientation     1000000 non-null float64
# lan             632473 non-null object
# h               1000000 non-null float64
# w               1000000 non-null float64
# ppi             1000000 non-null float64
# dtypes: float64(10), int64(1), object(18)
# memory usage: 221.3+ MB

# %%
traindata.columns
# Out:
# Index(['sid', 'label', 'pkgname', 'ver', 'adunitshowid', 'mediashowid',
#        'apptype', 'nginxtime', 'ip', 'city', 'province', 'reqrealip',
#        'adidmd5', 'imeimd5', 'idfamd5', 'openudidmd5', 'macmd5', 'dvctype',
#        'model', 'make', 'ntt', 'carrier', 'os', 'osv', 'orientation', 'lan',
#        'h', 'w', 'ppi'],
#       dtype='object')

# %%
###############################################################################
print(traindata['sid'].unique())

def deal_sid(df, **params):
    """
    处理sid
    :param df: 
    :param params: 
    :return: 
    """    
    df['sid'] = df['sid'].apply(lambda x: '-'.join(x.split('-')[:-1]))
    
    return df

deal_sid(traindata)

print(traindata['sid'].unique())
###############################################################################
# Out:
# ['d7460126-e071-4979-9ee8-42f72777a28a-1560090701088'
#  'b660d559-db97-4b5f-9bd2-2450cb89ce77-1560050740125'
#  'f49a740e-66c3-4605-9b67-4d3079fe69cb-1560089145219' ...
#  '76c2f123-0c57-4e2a-a8f3-0071084f9efa-1559560760099'
#  'c45f6f56-16df-4f98-9d31-2e5fa15994f2-1559541905808'
#  'aa31501c-28f5-4e37-82e3-1c1e1ae81758-1559518717557']
# ['d7460126-e071-4979-9ee8-42f72777a28a'
#  'b660d559-db97-4b5f-9bd2-2450cb89ce77'
#  'f49a740e-66c3-4605-9b67-4d3079fe69cb' ...
#  '76c2f123-0c57-4e2a-a8f3-0071084f9efa'
#  'c45f6f56-16df-4f98-9d31-2e5fa15994f2'
#  'aa31501c-28f5-4e37-82e3-1c1e1ae81758']

# %%
# 包名 经过MD5码 加密 【有重复值，有空值，建议one-hot】
print(traindata['pkgname'].unique())
print('\n')

# app版本 【很杂，建议剔除】
print(traindata['ver'].describe())
print('\n')

# 对外广告位 （广告显示的位置）【有重复值，无空值，建议one-hot】
print(traindata['adunitshowid'].describe())
print('\n')

# 对外媒体ID  【有重复值，无空值，建议one-hot】
print(traindata['mediashowid'].describe())
print('\n')
# Out:
# ['2d2664e827bcbb8b07100c7fbe072e9b' 'empty'
#  '16b81f93f4b1a35cebbf15f07683f171' ... '4510691cbea2d4e68b4161c2d626cf65'
#  '52cbed1ad7f2be37bf9c26b1f6f45662' '38256830b4b5336480fa4d1fb403fafd']
#
#
# count       678176
# unique        3182
# top       30927000
# freq         81783
# Name: ver, dtype: object
#
#
# count                              1000000
# unique                                 790
# top       f51ec99a47731ba46985a4530c923069
# freq                                 49059
# Name: adunitshowid, dtype: object
#
#
# count                              1000000
# unique                                 309
# top       d53d2af198ebef9544f0823c3c8e84f8
# freq                                188053
# Name: mediashowid, dtype: object

# %%
###############################################################################
# app所属分类  【有重复值，无空值，建议one-hot】
print(traindata['apptype'].value_counts())
print('\n')
# app所属分类  【有重复值，无空值，建议one-hot】
print(testdata_feature['apptype'].value_counts())
print('\n')

def deal_apptype(df, **params):
    """
    处理apptype
    :param df: 
    :param params: 
    :return: 
    """
    df['apptype'] = df['apptype'].apply(lambda x: str(x))
    
    return df

# app所属分类  【有重复值，无空值，建议one-hot】
print(traindata['apptype'].value_counts())
print('\n')
# app所属分类  【有重复值，无空值，建议one-hot】
print(testdata_feature['apptype'].value_counts())
print('\n')
###############################################################################
# Out:
# 301.0    202453
# 336.0     94193
# 326.0     80297
# 221.0     79289
# 318.0     72702
#           ...
# 274.0         1
# 297.0         1
# 253.0         1
# 311.0         1
# 203.0         1
# Name: apptype, Length: 91, dtype: int64
#
#
# 301.0    20556
# 273.0     8202
# 326.0     7907
# 221.0     7852
# 318.0     7309
#          ...
# 232.0        3
# 381.0        3
# 210.0        1
# 346.0        1
# 377.0        1
# Name: apptype, Length: 76, dtype: int64
#
#
# 301.0    202453
# 336.0     94193
# 326.0     80297
# 221.0     79289
# 318.0     72702
#           ...
# 274.0         1
# 297.0         1
# 253.0         1
# 311.0         1
# 203.0         1
# Name: apptype, Length: 91, dtype: int64
#
#
# 301.0    20556
# 273.0     8202
# 326.0     7907
# 221.0     7852
# 318.0     7309
#          ...
# 232.0        3
# 381.0        3
# 210.0        1
# 346.0        1
# 377.0        1
# Name: apptype, Length: 76, dtype: int64

# %%
# 请求到达服务时间
print(traindata['nginxtime'].unique())
print(traindata['nginxtime'].loc[0:3])
print('\n')
# Out:
# [1.56009070e+12 1.56005074e+12 1.56008915e+12 ... 1.55956076e+12
#  1.55954191e+12 1.55951872e+12]
# 0    1.560091e+12
# 1    1.560051e+12
# 2    1.560089e+12
# 3    1.560063e+12
# Name: nginxtime, dtype: float64

# %%
# 客户端IP地址
print(traindata['ip'].value_counts())
print('\n')
# 客户端IP地址
print(testdata_feature['ip'].value_counts())
print('\n')
# Out:
# 183.224.14.4      226
# 183.224.14.3      205
# 183.224.14.14     180
# 127.0.0.1         147
# 58.62.203.167     129
#                  ...
# 222.215.223.32      1
# 119.85.97.92        1
# 153.0.129.78        1
# 113.13.227.172      1
# 106.19.198.184      1
# Name: ip, Length: 747676, dtype: int64
#
#
# 58.62.204.11      55
# 183.224.14.4      26
# 183.224.14.3      26
# 125.77.22.197     17
# 183.224.14.14     15
#                   ..
# 223.91.87.184      1
# 111.146.40.45      1
# 222.81.52.74       1
# 223.91.224.255     1
# 121.31.247.126     1
# Name: ip, Length: 90931, dtype: int64

# %%
###############################################################################
# 城市
print(traindata['city'].unique())
print('\n')

# 省份
print(traindata['province'].unique())
print('\n')


def deal_city_province(df, **params):
    """
    处理城市和省份
    :param df: 
    :param params: 
    :return: 
    """
    import json
    # 中国省市编码地址
    china_city_list_path = project_path + '/data/foreign/china_city_list.json'
    
    # 省
    provinces = {}
    
    # 市
    cities = {}

    # 读取json
    with open(china_city_list_path, 'r') as file:
        # 读取所有省市数据
        china_city_list = json.load(file)
            
        for province in china_city_list:
            # key:province/value:code
            provinces[province['province']] = province['code']
            
            for city in province['cities']:
                # key:city/value:code
                cities[city['name']] = city['code']
    
    china_city_list = df['city']
    china_city_list = china_city_list.fillna(0)
    
    china_city_list_code = []
    china_province_list_code = []
    
    # 遍历获取code
    for city in china_city_list.values:
        # 是否在provinces中
        if city in dict.fromkeys(provinces.keys(), True):
            tmp = provinces[city]
            china_city_list_code.append(tmp)
            china_province_list_code.append(tmp[:2])
            
        # 是否在cities中
        elif city in dict.fromkeys(cities.keys(), True):
            tmp = cities[city]
            china_city_list_code.append(tmp)
            china_province_list_code.append(tmp[:2])
        
        # 不存在    
        else:
            china_city_list_code.append('100000')
            china_province_list_code.append('10')
            
            if city != 0:
                print(city)
    
    # 替换
    df['city'] = china_city_list_code
    df['province'] = china_province_list_code
                
    return df
    
traindata = deal_city_province(traindata)

# 城市
print(traindata['city'].unique())
print('\n')

# 省份
print(traindata['province'].unique())
print('\n')
###############################################################################

# %%
# 请求的http协议头携带IP，有可能是下游服务器的ip
print(traindata['reqrealip'].unique())
print('\n')
# Out:
# ['180.76.181.7' '47.95.111.138' '39.96.159.155' ... '113.57.183.75'
#  '122.190.154.66' '223.104.108.58']

# %%
# Adroid ID的MD5值
print(traindata['adidmd5'].unique())
print('\n')

# imei的MD5值  移动设备国际识别码，是手机设备的唯一识别号码
print(traindata['imeimd5'].unique())
print('\n')

# %%
###############################################################################
# idfa的MD5值
print(traindata['idfamd5'].value_counts())
print('\n')

# idfa的MD5值
print(testdata_feature['idfamd5'].value_counts())
print('\n')

def deal_idfamd5(df, **params):
    """
    处理idfamd5
    :param df: 
    :param params: 
    :return: 
    """    
    del df['idfamd5']
    
    return df
    

# idfa的MD5值
print(traindata['idfamd5'].unique())
print('\n')

# idfa的MD5值
print(testdata_feature['idfamd5'].unique())
print('\n')
###############################################################################

# %%
# openudid的MD5值
print(traindata['openudidmd5'].unique())
print('\n')

# mac的MD5值
print(traindata['macmd5'].unique())
print('\n')

# %%
###############################################################################
# 设备类型 0 – 未知,1 – PC,2 – 手机, 3– 平板,4– 电视盒,5– 智能电视,6 – 可穿戴设备,7 – 智能家电,8 - 音箱,9 - 智能硬件
print(traindata['dvctype'].value_counts())
print('\n')
print(testdata_feature['dvctype'].value_counts())
print('\n')

def deal_dvctype(df, **params):
    """
    返回设备类型
    :param df: 
    :param params: 
    :return: 
    """
    df['dvctype'] = df['dvctype'].apply(lambda x: str(x))
    
    return df

traindata = deal_dvctype(traindata)
testdata_feature = deal_dvctype(testdata_feature)

print(traindata['dvctype'].value_counts())
print('\n')
print(testdata_feature['dvctype'].value_counts())
print('\n')
###############################################################################

# %%
# 机型
print(traindata['model'].value_counts())
print('\n')


for key, value in traindata['model'].value_counts().items():
    print(key, value)
# Out:
# PBAM00                     26578
# PACM00                     23539
# PBEM00                     22510
# PADM00                     14363
# VIVO X21A                  13293
#                            ...
# SM-G950                        1
# BOWAY  T1+                     1
# G3                             1
# TETC_H1                        1
# HTC DESIRE 820 DUAL SIM        1
# Name: model, Length: 7719, dtype: int64
#
#
# PBAM00 26578
# PACM00 23539
# PBEM00 22510
# PADM00 14363
# VIVO X21A 13293
# MI 8 12895
# PBBM00 12435
# OPPO R9S 11382
# VIVO Y85A 10885
# OPPO A57 10863
# COL-AL10 10775
# EML-AL00 9366
# V1813A 9200
# PBAT00 9120
# VIVO X20A 8924
# V1809A 8606
# VIVO X9 8274
# PAR-AL00 8214
# OPPO R11 7977
# PAAM00 7874
# PACT00 7055
# PBCM10 6960
# V1816A 6914
# V1818A 6299
# OS105 5727
# OPPO R9M 5558
# OPPO R9SK 5545
# VIVO X7 5534
# OPPO A59S 5502
# OPPO R11S 5353
# VIVO Y83A 5253
# HMA-AL00 5219
# OPPO R9S PLUS 5009
# INE-AL00 4971
# VIVO Y66 4958
# MHA-AL00 4808
# PADT00 4749
# CLT-AL00 4646
# MI 8 LITE 4559
# OD103 4487
# JSN-AL00 4339
# PBET00 4266
# LYA-AL00 4241
# MI 8 SE 4226
# REDMI NOTE 7 4171
# VIVO Y85 4057
# V1818CA 3959
# VIVO X21I A 3954
# PBFM00 3922
# VIVO X21 3869
# PBCM30 3859
# PBBT00 3703
# VIVO Z1 3625
# V1813BT 3608
# JSN-AL00A 3585
# PAR AL00 3452
# COR-AL10 3440
# 16TH 3426
# JSN AL00 3420
# HWI-AL00 3412
# VIVO X9S 3387
# OPPO A57T 3367
# COL AL10 3367
# PAFM00 3305
# VIVO X21UD A 3261
# VIVO X20 3243
# MI 9 3208
# V1732A 3205
# JSN AL00A 3128
# INE AL00 3125
# VIVO Y55A 3114
# OPPO R9 PLUSM A 3081
# ANE-AL00 3063
# BKL-AL20 3042
# VIVO Z1I 2996
# OPPO R9 PLUSTM A 2964
# VTR-AL00 2939
# OPPO R11T 2929
# ONEPLUS A6000 2873
# GN5001S 996
# REDMI_5_PLUS 995
# OS103 984
# MIX 2 978
# M5 976
# NX563J 971
# HONOR COL-AL10 969
# VCE AL00 969
# 1505-A02 961
# MIX 2S 958
# SM-N9500 958
# RVL-AL09 957
# V1813BA 955
# SNE-AL00 949
# LYA-AL10 948
# VIVO X6A 944
# R8207 928
# BAC-AL00 922
# VIVO X5S L 919
# OPPO A73 918
# 15 917
# MI MAX 2 917
# BLN-AL10 915
# VIVO X6PLUS D 912
# 1713-A01 910
# 1503-A01 910
# VIVO 899
# V1831A 893
# VIVO XPLAY6 873
# GM1910 870
# PRA-AL00X 857
# VOG-AL10 852
# VIVO V3M A 852
# OPPO A83T 851
# REDMI NOTE 5 851
# ONEPLUS A6010 847
# YU FLY F9 845
# MI 9 SE 841
# VIVO Y31A 835
# 1809-A01 832
# MI MAX 831
# VOG-AL00 830
# VIVO Y13L 820
# CLT AL00 818
# TRT-AL00A 811
# VIVO XPLAY5A 810
# HUAWEI CAZ-AL10 809
# VIVO Y33 808
# HUAWEI HMA-AL00 804
# WAS-AL00 802
# VIVO Y66I 794
# BLN-AL40 770
# MI 9 TRANSPARENT EDITION 760
# BKK AL10 753
# ARE AL00 742
# DUB-AL00 738
# VIVO NEX S 728
# PBBT30 727
# OPPO 721
# GN9012 715
# VIVO Y75 714
# HUAWEI CLT-AL00 712
# OPPO R7 711
# MI+8 706
# VIVO Y31 699
# INE-TL00 689
# LE X620 689
# MIX 688
# REDMI NOTE 4 680
# ANE-TL00 670
# V1730EA 667
# VIVO X5MAX+ 663
# VIVO X5M 663
# SM-G9600 661
# VIVO Y79 654
# HUAWEI INE-AL00 636
# VIVO V3 632
# OPPO R11 PLUSKT 629
# VIVO Y13IL 628
# OPPO_R9SK 626
# BND-AL00 625
# MI_5X 621
# V1821A 619
# MAR-AL00 618
# PCT AL10 614
# VIVO X6SPLUS D 610
# M1822 610
# REDMI NOTE 3 598
# VIVO X5PRO D 593
# SM-G9350 585
# TNY-AL00 583
# GN5005 582
# VIVO Y29L 581
# MI PLAY 580
# RNE-AL00 579
# F5 573
# HONOR JSN-AL00 572
# 16S 571
# SNE AL00 569
# ONEPLUS A5000 563
# VIE-AL10 560
# BKL-AL00 559
# SM919 556
# A51 556
# MI 5 556
# M15 555
# M3S 550
# VIVO Y51T L 547
# M3 NOTE 542
# NX569H 541
# VIVO X20PLUS 541
# SM-G9750 541
# MI+6 539
# 2014813 535
# GN8003L 533
# ONEPLUS A5010 533
# VIVO Y37 530
# MI 5S PLUS 527
# A31C 526
# 1503-M02 524
# OPPO R9KM 522
# HUAWEI 520
# HUAWEI LYA-AL00 519
# PRA-AL00 513
# PLK-AL10 512
# JKM TL00 512
# ARS AL00 511
# BKK AL00 511
# 1501_M02 511
# REDMI 7 510
# SM-C9000 507
# ARE-AL00 504
# NOKIA X6 502
# OPPO R7SPLUS 500
# OPPO A77T 500
# VIVO X9PLUS L 499
# 1807-A01 499
# VIVO Y28L 496
# GN9011 495
# EML-TL00 493
# 1711-A01 492
# GIONEE S10 492
# VIVO X3L 492
# NEM-AL10 490
# ANE TL00 490
# M1 E 490
# MX5 486
# FRD-AL00 486
# OPPO R11 PLUSK 476
# OPPO A37T 473
# MAR AL00 462
# VIVO Y35 461
# LENOVO L78011 460
# REDMI NOTE 5A 460
# SM-C7000 458
# SM-G9730 457
# GN9010 456
# JSN-TL00 455
# DIG-AL00 452
# HRY-AL00 448
# OPPO A53M 447
# PAHM00 444
# JKM AL00A 444
# MI 5S 444
# HONOR JSN-AL00A 444
# 1603-A03 437
# SKR-A0 435
# REDMI 4X 433
# JKM-TL00 432
# M3 431
# PIC-AL00 430
# HUAWEI VCE-AL00 428
# OPPO_R9_PLUSTM_A 427
# NOTE9 425
# F100S 421
# R9M 421
# LND-AL30 420
# HUAWEI ANE-AL00 418
# SM-N9600 404
# M621C 403
# RVL AL09 403
# OPPO A73T 401
# FLA-AL10 397
# BKK-AL10 392
# HRY AL00 386
# M2 E 381
# OPPO A79 379
# PCCM00 377
# SM-G9280 376
# INE TL00 374
# REDMI 5A 371
# R7C 371
# GN8001 371
# SLA-AL00 371
# REDMI_NOTE_4X 367
# JKM-AL00A 366
# ELE AL00 365
# HUAWEI RIO-AL00 365
# HWI-TL00 364
# V1731CA 363
# M2 360
# PAR-TL00 359
# VIVO Y35A 359
# BLN-AL20 358
# LYA AL00 358
# LDN-AL00 357
# GN8002 354
# MP1602 353
# GN3001 353
# KNT-AL20 350
# PCAT10 347
# CUN-TL00 347
# ARS-AL00 346
# A59S 345
# M3X 344
# OPPO A53 343
# V1824BA 342
# F100L 341
# GIONEE M7 340
# COR AL00 340
# VIVO X6PLUS A 340
# JSN TL00 339
# G0215D 337
# OPPO_R9S_PLUS 337
# VIVO NEX 335
# HUAWEI TAG-AL00 335
# COL-TL10 335
# OPPO_A57T 333
# GN3003 330
# GN5005L 330
# GAPPS 1 327
# PCAT00 327
# SM G9500 325
# LLD-AL00 323
# FLA-AL20 323
# MEIZU S6 322
# DUB TL00 320
# OPPO R11S PLUST 319
# NX549J 317
# VIVO Y53 316
# A 314
# VIVO X5L 313
# GIONEE S10L 311
# JAT AL00 310
# VIVO X21UD 308
# OPPO R9S PLUST 306
# OPPO R9T 305
# REDMI NOTE 2 305
# GIONEE GN5007 304
# NX609J 304
# HONOR LLD-AL20 303
# VIVO X5PRO V 302
# OPPO+A57 300
# HMA-TL00 299
# OPPO A79K 299
# REDMI K20 PRO 299
# LLD-AL10 298
# 1803-A01 295
# OPPO_R9_PLUSM_A 295
# DUA-AL00 295
# EVA-AL00 293
# SM G9550 292
# NX595J 290
# MP1718 290
# CLT AL01 289
# HUAWEI TAG-TL00 289
# VTR-TL00 288
# REDMI 5 287
# VIVO X6L 285
# TRT-TL10A 284
# FIG-AL10 282
# 16TH PLUS 281
# HONOR PCT-AL10 279
# EDI-AL10 279
# ZTE V0840 278
# 1509-A00 278
# HUAWEI ELE-AL00 278
# MEIZU M6 275
# REDMI 4A 274
# M654 274
# CUN-AL00 272
# EVR AL00 270
# KNT-AL10 268
# OPPO+R11 268
# M1813 267
# NX531J 266
# BKK-AL00 265
# 1701-M01 264
# TRT-AL00 262
# HONOR COR-AL10 262
# A31T 262
# HUAWEI JKM-AL00B 258
# MI 8 EXPLORER EDITION 258
# PCGM00 258
# GIONEE S10C 257
# OPPO_A59S 256
# MI8 256
# SM-C5000 255
# MI MAX 3 252
# HLTE200T 251
# OPPO R9SKT 251
# 16 X 249
# PLK-TL01H 249
# JAT-AL00 247
# MIX+2S 246
# MP1701 246
# POT-AL00A 245
# BLN-TL10 244
# POT AL00A 241
# BND-TL10 241
# DUB AL20 240
# REDMI 6 239
# VIVO%20Y85A 239
# KIW-AL10 237
# CAM-AL00 236
# OPPO+R9S 236
# GIONEE S10CL 235
# MI 4LTE 234
# OPPOR11 234
# OPPO_R9M 232
# REDMI 3S 232
# HUAWEI MT7-TL10 230
# MP1603 230
# MI+9 230
# HUAWEI JKM-AL00 228
# R7PLUST 227
# R8107 226
# M2 NOTE 225
# VIVO X710L 224
# N5207 223
# ALP-TL00 223
# HONOR 221
# ONEPLUS A3010 221
# A11 221
# YQ601 220
# 1603-A02 219
# PAFT00 219
# MIX+2 219
# REDMI 6A 218
# EVA-TL00 218
# VIVO Y53L 217
# 6607 216
# GIONEE M7L 216
# HUAWEI DUB-AL00 216
# M1 METAL 216
# R9TM 215
# HM NOTE 1LTE 214
# OC106 214
# MP1709 214
# HLTE300T 213
# V1829T 211
# JMM-AL10 211
# V1814T 209
# N5117 209
# LETV X500 208
# HONOR HRY-AL00A 208
# JMM-AL00 208
# R8205 207
# VIVO X5V 207
# M653 207
# VIVO Y923 206
# MP1503 205
# HONOR LLD-AL30 205
# VIVO Y18L 205
# 4G+ 203
# X7 202
# HUAWEI EVR-AL00 201
# MTS-T0 200
# MI+8+SE 200
# XIAOMI 198
# OPPOA59S 197
# REDMI_5A 197
# S9L 196
# H60-L01 196
# RMX1901 196
# MI+NOTE+3 196
# VIVO XPLAY3S 193
# OPPO A79T 193
# DLI-AL10 192
# X9007 192
# LE X820 190
# PRO 6 190
# MYA-AL10 189
# REDMI 4 189
# OPPOR9M 189
# M652 188
# LETV X501 188
# LEPHONE T7A 186
# F100 185
# MP1512 184
# OPPOR9S 184
# G8142 184
# NX575J 184
# MI NOTE LTE 183
# NCE-AL10 183
# OPPO_R9ST 183
# SM-N9008V 183
# OPPOA57 181
# X6D 180
# HUAWEI P8MAX 180
# HUAWEI TIT-TL00 179
# HUAWEI TIT-AL00 179
# VIVO Y75S 179
# 1515-A01 179
# DUB-TL00 178
# REDMI_4X 178
# MI NOTE 2 177
# YAL-AL00 177
# M721C 177
# 4G 177
# HUAWEI CLT-AL01 176
# PRO 7 PLUS 176
# HUAWEI GRA-UL10 175
# HUAWEI VNS-AL00 175
# REDMI 3 175
# SM901 175
# MI_NOTE_3 174
# F105 173
# R7007 172
# A37M 172
# SM-G9250 171
# NOKIA X7 171
# VIVO X7L 169
# NX573J 169
# MI+6X 169
# PRA-TL10 168
# OPPO A59ST 168
# VIVOX21A 168
# ATH-AL00 167
# NX589J 166
# U20 166
# PRO 6S 166
# V1836A 165
# NX619J 165
# A59M 162
# NX569J 162
# HRY-AL00TA 161
# LEX720 161
# SM-C7010 161
# REDMI_5 161
# PRO 6 PLUS 161
# SM-G9508 159
# BAC-TL00 159
# M636 159
# DRA-AL00 159
# GIONEE GN5007L 159
# WAS-TL10 157
# HUAWEI GRA-TL00 157
# VIVO Y913 157
# CAM-TL00 156
# HM NOTE 1S 156
# VIVO X20PLUS UD 155
# TRT-TL10 155
# VIVO Y13 155
# SM-A7000 154
# M6SPLUS 153
# M6 151
# SM-A6050 150
# M821 150
# VIVO+X21A 149
# 8676-A01 149
# V1901A 149
# HUAWEI LYA-AL10 147
# MP1605 147
# SKW-A0 147
# NX611J 146
# G0245D 146
# NOKIA X5 146
# EML TL00 146
# SM-G8850 146
# 1107 146
# LYA-TL00 145
# NX529J 144
# CHM-TL00 144
# C106 144
# ATU-AL10 143
# HUAWEI NXT-TL00 142
# LYA-AL00P 142
# ONEPLUS A3000 142
# MX4 141
# SM-G8870 141
# SM-C7100 141
# DIG-TL10 140
# M571C 140
# VIVO_X9 140
# LEPHONE T7+ 139
# BTV-W09 139
# MHA-TL00 139
# SUGAR Y12 138
# V1838T 138
# SLA-TL10 137
# ONEPLUS+A6000 137
# PRO 7-S 137
# VIVO Y22IL 136
# F106 136
# OPPO-A57 136
# NCE-AL00 135
# KNT-UL10 135
# HONOR ARE-AL00 135
# OPPO_A37M 135
# HM 2A 135
# VIVO X3V 135
# SM-A9000 134
# SM-A5000 134
# OPPO+R11S 134
# HUAWEI VOG-AL10 134
# ARE-AL10 133
# R6007 133
# HONOR RVL-AL09 133
# PAR TL00 132
# TNY AL00 130
# STF-TL10 130
# LDN-AL20 129
# R8007 129
# OPPO+R9SK 128
# VIVO%20X21UD%20A 128
# REDMI+NOTE+5 128
# NX616J 128
# F103 128
# R7T 128
# MEIZU E3 127
# PLE-703L 126
# M1 125
# VIVO Y927 125
# A31U 124
# ARE AL10 122
# CHM-TL00H 122
# AUM-AL20 121
# KIW-TL00 121
# DUK-TL30 121
# SM-N9200 121
# PE-TL10 121
# A33 120
# REDMI+NOTE+7 120
# CRUISE 120
# HUAWEI ANE-TL00 120
# MI_6 120
# PRO 5 120
# OPPO A79KT 120
# HUAWEI CAZ-TL20 119
# MI6X 119
# REDMINOTE7 119
# TA-1000 118
# LEX626 118
# MI-4C 118
# HUAWEI VOG-AL00 117
# M3 MAX 117
# V1832A 117
# UNKNOWN 116
# M623C 116
# OPPO_R7 115
# LEPHONE T13 115
# GN3002 115
# HUAWEI SNE-AL00 114
# HUAWEI INE-TL00 114
# HRY AL00TA 114
# HUAWEI CRR-UL00 114
# OPPO_R9TM 114
# SM-G6100 114
# F106L 114
# M651CY 114
# VIVO_X20A 114
# X7PLUS 114
# FIG-AL00 113
# U10 112
# OPPO%20R11S 112
# REDMI S2 112
# MHA AL00 112
# OPPO_A59M 112
# SM G9650 111
# OPPO%20R9S 110
# SM-A9200 110
# OPPOR11S 110
# NEO-AL00 110
# W909 110
# 1703-M01 109
# COOLPAD 5370 109
# M2017 109
# HUAWEI ARS-AL00 109
# OPPOA83 108
# VIVO X6SPLUS A 108
# HUAWEI MAR-AL00 107
# OPPO+R9M 106
# MI+8+LITE 106
# CHM-CL00 106
# BND AL10 106
# HLTEM800 105
# SCL-TL00 105
# DUB-AL20 105
# HUAWEI MT7-CL00 105
# VIVO Y623 104
# OPPO PBAM00 104
# CHE1-CL10 104
# KONKA 509 104
# MI%208 104
# AUM-AL00 103
# SM-N9006 103
# HUAWEI VNS-TL00 103
# SM-C5010 103
# CLT-TL00 103
# HUAWEI MLA-TL10 103
# V1831T 102
# HLTE213T 102
# R7S 102
# HLTE200M 101
# SM-G8750 101
# SM-J5008 101
# REDMI PRO 101
# VIVO Y69A 100
# OPPO R7ST 100
# SM-A9100 100
# VIVO Y22L 100
# VIVOY85A 100
# ZTE A0616 99
# GN3003L 99
# 1501-A02 99
# VIVO+X9 99
# OPPO-R9S 99
# HLTE310M 99
# TA-1041 98
# OPPO+A57T 98
# HLTE510T 98
# SM-G9200 98
# VIVO X3F 98
# R2017 97
# U19 97
# VIVOX9 97
# OPPO+R11T 97
# GIONEE F6 96
# SM-G9300 96
# M760 96
# MI8LITE 96
# VIVO X5MAX L 95
# FS8010 95
# R7SM 95
# PBDT00 95
# PE-TL20 94
# OPPOR9SK 94
# C106-9 94
# KONKA D6+ 94
# MI8SE 94
# FIG-TL10 93
# NX629J 93
# HONOR COR-AL00 93
# X23 93
# GN5002 93
# LE X528 93
# EVA-DL00 92
# GIONEE S10B 91
# SM801 91
# M57AC 91
# R831S 91
# M711C 91
# SM-G6000 91
# MI+5X 90
# R7005 90
# X900 90
# OPPOR11T 89
# OPPO A33T 89
# M6+NOTE 89
# OPPO%20A57 89
# VIVO+X20A 89
# MI_5S 88
# H60-L03 88
# SM-J7008 88
# VKY-TL00 88
# KOOBEE S106M 88
# HONOR JSN-TL00 88
# VIVO Y937 88
# HISENSE F23 88
# X600 88
# GN9006 88
# HISENSE F22 88
# HUAWEI JKM-TL00 87
# BKL-TL10 87
# OPPO+A59S 87
# R7 87
# R9 87
# HONOR BKK-AL10 87
# COL TL10 86
# OPPO%20R11 86
# M A5 86
# HUAWEI MLA AL10 86
# VIVO X6PLUS L 86
# VIVO_X7 86
# ONEPLUS+A5010 85
# PCDM00 85
# M5_NOTE 85
# MIX+3 85
# GT-N7100 85
# FLA-TL10 84
# MI 84
# HMA TL00 84
# REDMI+5+PLUS 84
# TRT AL00A 84
# SM N9500 83
# REDMI+NOTE+4X 83
# M850 83
# NOKIA 7 PLUS 83
# PCEM00 83
# HUAWEI NXT-DL00 83
# REDMINOTE4X 83
# XIAOMI_MI-MAX 83
# 8681-A01 83
# MRD-AL00 83
# LEPHONE T25 82
# COR-TL10 82
# R9S 82
# GET 82
# XIAOMI_MI-5 82
# Y51 82
# VIVOX20A 81
# RMX1851 81
# 3007 81
# M1 NOTE 81
# 20161220 80
# VIVO Y37A 80
# VIVO+Y85A 80
# OPPO+R9S+PLUS 79
# GEM-703L 79
# COMIO A8 79
# ONEPLUS+A5000 79
# MI_5S_PLUS 79
# MP1611 79
# VOG AL00 78
# EVB3561SV_W_65_M0 78
# SM-N9002 78
# BKK TL00 78
# SM-N9008 78
# OPPOA37M 78
# OPPOR9SPLUS 77
# VIVO XPLAY6L 77
# HUAWEI G7-TL00 77
# HUAWEI JKM-AL00A 77
# HONOR HRY-AL00 77
# BLN AL10 77
# DLI-TL20 76
# VIVO%20Y85 76
# HWI AL00 75
# SM-G5500 75
# MI 5C 75
# PE-CL00 75
# PIC-TL00 75
# CHM-UL00 75
# HLTE310T 74
# REDMI 3X 74
# VIVO Y17T 74
# SM-A7100 74
# 8681-M02 74
# COOLPAD 8737A 73
# VCE-TL00 73
# VIVO Z3X 73
# VIVO X23 73
# N5209 73
# BTV-DL09 73
# NX541J 72
# SAMSUNG 72
# LYA AL10 72
# Y1 72
# F100A 72
# PRO 7-H 72
# BLN AL40 72
# SM705 72
# VIVO+Y66 71
# LE X520 71
# VIVO X5MAX S 71
# CLT-TL01 71
# HUAWEI CAZ AL10 71
# COOLPAD 8675-A 70
# MP1710 70
# NX612J 70
# REDMI+NOTE+7+PRO 70
# MAR-TL00 70
# OPPOR9TM 70
# SM A6050 70
# KIW-TL00H 69
# MI%208%20SE 69
# OPPO-R9-PLUSTM-A 69
# KOOBEE S305M 69
# G8342 69
# VIVO%20X21 69
# HRY-AL00T 68
# ZTE BA510 68
# MI NOTE PRO 68
# SM-N9100 68
# GIONEE S10BL 68
# HUAWEI HMA-TL00 67
# Y67 67
# LND-AL40 67
# M1816 67
# DUK AL20 66
# MRD AL00 66
# ZUK Z2121 66
# CMCC M761 66
# IVVI V3 66
# MUMU 65
# VIVO X510T 65
# M578C 65
# HUAWEI GRA-CL00 65
# REDMI5PLUS 65
# OPPO R7T 65
# VIVOX21UDA 65
# XIAOMI MI 8 64
# HONOR TNY-AL00 64
# VIVO_X9PLUS 64
# HUAWEI_NXT-AL10 64
# LENOVO L78071 64
# VIVO+X7 64
# OPPO PBEM00 64
# HUAWEI M2-803L 64
# FRD AL10 64
# ZTE A2017 63
# SM-N9009 63
# HUAWEI NXT AL10 63
# HONOR JAT-AL00 63
# MI9 63
# BKL AL20 63
# LE X621 63
# HUAWEI MT7-TL00 63
# VIVO Y627 63
# MEIZU 6T 62
# CHE2-TL00M 62
# X6A 62
# LEX622 62
# NOAIN F2016 62
# HUAWEI CAZ-TL10 62
# BLA-TL00 62
# VIVO V3MAX 62
# CK3-01 62
# VIVO V3MAX L 61
# A0001 61
# GIONEE F6L 61
# VOG AL10 61
# NOTE 61
# 2014811 61
# MI6 61
# OPPO+A83 61
# HUAWEI PAR-TL00 61
# VIVO-Y85A 60
# E2 60
# OPPO-R11 60
# ZUK Z2131 60
# C8816 60
# MI+9+SE 60
# XPLAY5A 60
# SM G8850 60
# OPPOR11ST 60
# OPPO_R11 59
# ALP AL00 59
# M850A 59
# 2014501 59
# SM-A8000 59
# VIVO Y613F 59
# VIVO_Y66 59
# ONEPLUS 59
# HUAWEI GRA-UL00 58
# LDN-TL20 58
# NX606J 58
# OPPO+R9TM 58
# M836 58
# REDMI-NOTE-7-PRO 58
# R5 58
# G750-T00 58
# PRA AL00X 58
# VIVO_X20 58
# OPPO_R11S 58
# DUB AL00A 57
# F100SL 57
# HLTE500T 57
# BLN-AL30 57
# V21(X21S) 57
# VIVO S7I(T) 57
# VIVO Y13T 57
# VIVO%20X21A 57
# SM G9600 57
# OPPOA59M 56
# MP1713 56
# REDMI6PRO 56
# VIVO%20X9 56
# PLK-TL00 56
# OPPOR11PLUS 56
# ELE-TL00 55
# OPPO%20R9SK 55
# M631 55
# A57 55
# VIVO%20Z1I 55
# EYU T31 55
# VIVOX7 55
# JAT TL00 55
# ZTE BV0710 55
# OPPO%20R9S%20PLUS 55
# OPPOA57T 55
# CLT-L29 55
# SM-G955N 54
# HRY TL00 54
# U28 54
# OPPO A30 54
# HONOR BKK-AL00 54
# HLTE212T 54
# LND AL30 53
# HUAWEI DUB-TL00 53
# REDMINOTE5 53
# X9077 53
# VIVO_X9S_PLUS 53
# MI 4S 53
# H30-T00 53
# HUAWEI GRA-CL10 53
# ZTE BA520 53
# KIW-CL00 53
# VIVO%20X21I%20A 53
# Y55A 53
# R11S 53
# COOLPAD 8737 53
# GM1900 53
# C106-8 52
# MI5X 52
# Y51A 52
# MIX_2 52
# SM-G7200 52
# STF AL10 52
# SLA AL00 52
# TRT TL10A 52
# LYA-L29 52
# SAMSUNG_MOBILE-OTHERS 52
# REDMI_6_PRO 52
# OPPO PBBM00 52
# VIVOY66 52
# TA-1054 52
# CAM-TL00H 52
# N9180 52
# FLA AL10 52
# VIVO-X21A 52
# OPPOA73 51
# VK 7 PLUS 51
# SM-N950N 51
# PLUS 51
# S898T+ 51
# 2014812 50
# R11 50
# BKK-TL00 50
# VIVO X3T 50
# M611D 50
# HUAWEI ALE-CL00 50
# COMIO T9 50
# M2018 49
# ARS TL00 49
# VIVO+X21UD+A 49
# SM G8870 49
# MIMAX2 49
# R9KM 49
# Y7 49
# H8296 49
# 15 PLUS 49
# COMIO M7000+ 49
# A680Q 48
# 8692-M02 48
# HISENSE M36 48
# HLTE215T 48
# VIVO-Y55A 48
# SM-N9008S 48
# ZTE BV0730 48
# PRA AL00 48
# FS8018 48
# 1105 48
# 16TH+PLUS 48
# 1801-T0 47
# VIVO%20Y83A 47
# R8200 47
# OPPO-R9SK 47
# SM-G9008V 47
# VIVO X23 MAGIC COLOR 47
# S90-T 47
# LEPHONE V5 47
# HN3-U01 47
# XS 47
# VIVO X5MAX V 47
# SM-G9700 47
# OPPO+A59M 47
# ALE-TL00 47
# H60-L11 47
# OPPO+R9+PLUSM+A 47
# VIVO Y928 47
# SM-J3110 47
# HUAWEI B199 47
# 8675-HD 46
# MI_6X 46
# M823 46
# CHE1-CL20 46
# 8692-A00 46
# NEM-TL00 46
# SM-A6060 46
# VIVOX21 46
# SCL-AL00 46
# SCL-CL00 46
# TRT TL10 46
# OPPOA83T 46
# PE-TL00M 46
# LEX651 46
# TRT AL00 46
# SM-G955F 46
# SM-J5108 45
# A33M 45
# VIVO%20X7 45
# VIVO Z3 45
# G750-T01 45
# M3_NOTE 45
# D 45
# X608 45
# VIVO+NEX+S 45
# OPPO+A37M 45
# 8076 45
# OPPO+R9ST 45
# X9 45
# OPPOR9PLUSMA 44
# CPN-AL00 44
# VIVO-Y66 44
# VIVO+NEX+A 44
# MI+8+UD 44
# VIVO X7PLUS L 44
# KOOBEE S106 44
# VIVO+X21 44
# OPPO_A33M 44
# OPPO+R9+PLUSTM+A 44
# NX523J_V1 44
# VIVO X6SPLUS 44
# HUAWEI POT-AL00A 43
# GN3001L 43
# HUAWEI_P9 43
# SM-J3119 43
# MINOTE3 43
# VIVO VIVO Y85A 43
# OPPOA77 43
# PCT-TL10 43
# DIG AL00 43
# SAMSUNG_GALAXY-S7-EDGE 43
# SM-N9005 43
# VIVOZ1 43
# MI%208%20LITE 43
# VIVO_X9S 42
# WAS AL00 42
# ALE-UL00 42
# 20170829D 42
# HUAWEI VNS-DL00 42
# COOLPAD 8675-HD 42
# CUN AL00 42
# OPPO PACM00 42
# HUAWEI EML-TL00 42
# YQ603 42
# IVVI F2-T 42
# SM-G6200 42
# VIVO Y11 42
# GAPPS 0 42
# REDMINOTE7PRO 42
# BND AL00 42
# I939D 42
# NCE-TL10 42
# VIVO Y93 42
# MYA-TL10 42
# S2 42
# CAM-UL00 42
# HUAWEI RIO-TL00 41
# LENOVO L38012 41
# AWM-A0 41
# Y67A 41
# K-TOUCH K5 41
# VIVO Y53N 41
# VIVO_X7PLUS 41
# SM-N7508V 41
# HUAWEI G7-UL20 41
# REDMI_NOTE_7 41
# HUAWEI MLA-AL00 41
# SM-J7108 41
# REDMI%20NOTE%204 41
# VIVO+Y55A 41
# G6 40
# MAR TL00 40
# N919D 40
# SM-G950F 40
# F8 40
# HUAWEI CRR-CL00 40
# 8676-M01 40
# V183 40
# V15 40
# KIW-UL00 40
# COMIO M7000 40
# FLA AL20 40
# VIVOZ1I 40
# MX4 PRO 40
# VCE TL00 40
# HRY AL00T 40
# OPPOR11SPLUS 40
# D820U 40
# OPPO R9 PLUST A 39
# HUAWEI TIT-CL10 39
# MI 2S 39
# ONEPLUS+A6010 39
# OPPO PBAT00 39
# MI 2SC 39
# T939 39
# VIVO Y20T 39
# 2014011 39
# MI+MAX+2 39
# JAT-TL00 38
# EVA AL10 38
# ZTE BA611T 38
# VTR AL00 38
# VIVO%20X20A 38
# 7088 38
# SM-A5100 38
# ONEPLUSA6000 38
# COOLPAD 8722V 38
# REDMI%206%20PRO 38
# KNT-TL10 38
# OPPO-A57T 37
# OPPO-A59S 37
# VIVO_X9L 37
# VIVO+Y23L 37
# LLD-TL10 37
# CHE-TL00H 37
# HISENSE E76 37
# REDMI+K20+PRO 37
# OPPO+A77 37
# VOG-TL00 37
# XIAOMI_REDMI-NOTE-3 37
# MI_8 37
# VCR-A0 37
# VIVOX9S 37
# R7SPLUS 37
# VIVO+Z1 37
# VIVO+X9S 37
# INE-LX2 36
# SM-G5700 36
# MI+MAX+3 36
# NEM AL10 36
# OPPOA79 36
# A320T 36
# C1 36
# KOOBEE S305 36
# LENOVO K320T 36
# L820 36
# SM-N9108V 36
# OPPO-A37M 36
# HLTE210T 36
# ONEPLUS%20A6000 36
# VIVO Y97 36
# M5NOTE 36
# XT1662 36
# RNE AL00 36
# VIVO%20NEX%20A 36
# 8079 35
# REDMINOTE3 35
# VIVOX20 35
# SHT-W09 35
# OPPO+A73 35
# MI PAD 4 35
# OPPO_R9S_PLUST 35
# X501 35
# VIVOX21IA 35
# Y3 35
# KINGSUN-F9 35
# JDN-W09 35
# VIVO V1813A 35
# GN3002L 35
# PLK-CL00 35
# LEPHONE T11 35
# X820 35
# ZTE BV0720 35
# P709 35
# VIVOX9PLUS 35
# Z999 34
# GALAXY S4 ZOOM 34
# V1821T 34
# MIMAX3 34
# GT-S7562I 34
# LND-TL40 34
# SM-J3300 34
# M6NOTE 34
# VIVOY85 34
# COMIO M5000 34
# OPPO-A83 34
# EML-L29 34
# OPPO-R9S-PLUS 34
# SM-J3109 34
# DAZEN 6A 34
# ARS-TL00 34
# ZTE BA910 34
# ATU-TL10 34
# FRD-DL00 34
# A670T 34
# SM-A7108 34
# BOWAY U16 34
# VIVO+Y85 34
# T780 34
# HUAWEI+NXT-AL10 34
# BEST SONNY LT999 34
# VIVOY67A 34
# MI+5 34
# D310W 34
# SM-G5510 34
# LENOVO L38041 33
# N1T 33
# LDN AL00 33
# VIVO X3S W 33
# Q505T 33
# DLI AL10 33
# SM-G5308W 33
# HM NOTE 1LTETD 33
# R3 33
# MIX2 33
# ONEPLUS+A3010 33
# OPPO%20A59S 33
# HUAWEI NXT-CL00 33
# SM-G9208 33
# EYU T7 33
# LEPHONE T10 33
# A238T 33
# HUAWEI C8818 33
# OPPO-R11T 33
# A808T 33
# KOOBEE X905Q 33
# ZTE A530 33
# ARE TL00 32
# SCH-I679 32
# 1812-A0 32
# VIVO Y613 32
# VIVO Y11I T 32
# SM A9200 32
# OPPO%20R9%20PLUSTM%20A 32
# A396 32
# GN9010L 32
# HRY-TL00 32
# S39H 32
# OPPO%20R9M 32
# PLK-UL00 32
# OPPO PADM00 32
# VIVOY83A 32
# I9158 32
# X620 32
# GT-S7572 32
# SM-N950F 32
# STF AL00 32
# HUAWEI M2-A01L 31
# JDN-AL00 31
# OPPO%20R11T 31
# 16+X 31
# SM-G7508Q 31
# GT-I9500 31
# KNT AL10 31
# M5+NOTE 31
# A83 31
# HUAWEI+MLA-AL10 31
# M612C 31
# VIVO-X9 31
# Y3T 31
# ZTE A2015 31
# DUA-TL00 31
# SCL-TL00H 31
# CHANGHONGS06 31
# ZTE A0622 31
# LLD AL10 31
# CHE2-TL00 31
# 5217 31
# I7S(YP7S) 30
# H60-L02 30
# VIVO%20Y66 30
# MI 3 30
# T106 30
# REDMI+NOTE+4 30
# VIVO-Y51 30
# OPPOA79K 30
# VIVONEXA 30
# COR TL10 30
# HISENSE F23M 30
# OPPO_R11T 30
# M652YN 30
# R11T 30
# NX608J 30
# GIONEE_GN5007 30
# GOME 2017M27A 29
# DAZEN 6 29
# R11ST 29
# HLTE311T 29
# W656 29
# SM-G9209 29
# KOOBEE M9 29
# SM-G3589W 29
# SM-N960N 29
# PIC AL00 29
# HUAWEI_MLA-AL10 29
# VIVO+X21I+A 29
# PCDM10 29
# Y600D-C00 29
# LEPHONE T9+ 29
# OPPO-R11S 29
# VIVO+Y83A 29
# VIVO+Y51A 29
# 8122 29
# AUM-TL20 29
# DUB-AL00A 29
# D610T 29
# HUAWEI TAG AL00 29
# BF T26 29
# SM-G7106 29
# A690 29
# COOLPAD B770 29
# MHA-L29 29
# REDMI 28
# LEX722 28
# XIAOMI MI 8 LITE 28
# COMMON 28
# FIG AL10 28
# X800 28
# OPPOR9ST 28
# COOLPAD 8712 28
# SUGAR Y9 28
# OPPO+A33M 28
# G13 28
# SM-G965N 28
# MI8UD 28
# ZTE V0920 28
# HUAWEI VCE-TL00 28
# X900+ 28
# VIVO Y15T 28
# DOOV L9 MINI 28
# REDMI+6+PRO 28
# HUAWEI_CAZ-AL10 28
# SM-A5009 28
# X22 28
# MI+5S 28
# HUAWEI P7-L07 28
# GN5001 28
# MIX2S 28
# AGM X2 27
# OPPO+R11+PLUS 27
# EYU T53 27
# T3 27
# OPPO+R11ST 27
# VKY AL00 27
# MI_8_SE 27
# VIVO-Y83A 27
# SAMSUNG_GALAXY-S6-EDGE 27
# MI 3W 27
# 7060 27
# LENOVO K30-T 27
# W68 27
# VIVO-Y85 27
# SM-A7009 27
# ZTE BV0710T 27
# GIONEE S11 27
# HUAWEI_P9-PLUS 27
# BAH-W09 27
# X528 27
# LENOVO L58041 27
# HISENSE E77 27
# VIVO-Z1 27
# MI+5S+PLUS 27
# NX907J 27
# VOG-L29 27
# Y35 27
# V1911A 27
# HISENSE E76MINI 26
# VIVO+X20 26
# DOOV L8 PLUS 26
# REDMI_NOTE_4 26
# HONOR ARE-AL10 26
# VIVO+Z1I 26
# OPPO%20R9TM 26
# BAC AL00 26
# REDMINOTE4 26
# REDMI%20NOTE%207 26
# BLA AL00 26
# ART-T0 26
# OPPO_A33 26
# A53M 26
# A57T 26
# 3 26
# NX591J 26
# TOU CH 2 26
# KOOBEE S309 26
# BEST SONNY LT558 26
# LENOVO A6800 26
# SM-G5520 26
# CUN TL00 26
# HUAWEI DUB-AL20 26
# UNC-A2 26
# 5860S 25
# DOOV A5 25
# OPPO%20R11ST 25
# POT TL00A 25
# VIVO+X9PLUS 25
# VIVOX9I 25
# VIVO_X6S_A 25
# OPPO_R9SKT 25
# NEM-UL10 25
# REDMI4X 25
# HUAWEI TIT TL00 25
# SM-G950N 25
# VIVOY67 25
# R6 25
# SM-A7050 25
# JMM AL10 25
# MIX3 25
# MI_MAX_2 25
# HUAWEI M2-801W 25
# MI+9+TRANSPARENT+EDITION 25
# LLD AL00 25
# WP 25
# VIVO+Y67A 25
# M685C 25
# LENOVO A3860 25
# SM-N9109W 25
# LDN-TL00 25
# A1601 25
# NEXUS%205 25
# ONE A2001 24
# OPPO-R9-PLUSM-A 24
# COOLPAD 5267 24
# LEX650 24
# VIVO_Y85A 24
# 8848 M3 24
# JMM AL00 24
# VIVO_Y51 24
# COOLPAD Y1 24
# FULL_HCT6753_35GC_L1 24
# COOLPAD 8297-T01 24
# COOLPAD Y803-9 24
# NX551J 24
# VIVO_X9I 24
# VIVO Z3I BASIC 24
# Y67L 24
# OPPO+A83T 24
# NEM-TL00H 24
# GT-S7898I 24
# VIVO_V3MAX_A 24
# VIVOX7PLUS 24
# VIVO XPLAY5S 24
# VIVO+Y51 24
# SAMSUNG_GALAXY-A7 24
# VOTO GT11 PRO 24
# VIVO XPLAY 24
# XIAOMI MI 8 SE 24
# LENOVO L78031 24
# CPN-W09 24
# VIVO VIVO X21A 24
# GOME 2017X82A 24
# KOPO L6 24
# LEPHONE T16 24
# UOOGOU 23
# HUAWEI+CAZ-AL10 23
# S7568 23
# VIVOV3MAXA 23
# MEIZU+S6 23
# VIVO-X21I-A 23
# HUAWEI LYA-AL00P 23
# YQ607 23
# VIVO X5PRO L 23
# VIVO-X20A 23
# M5-NOTE 23
# NCE AL10 23
# BF T61 23
# VIVO+X9I 23
# SLA TL10 23
# SM-E7000 23
# L 23
# VIVO V1816A 23
# VIVO_X9S_L 23
# DOOV L520 23
# HLTE100M 23
# OPPO%20R11%20PLUS 23
# XIAOMI REDMI NOTE 7 23
# AX9 23
# FRD AL00 23
# LEPHONE W7+ 23
# S3 PRO 23
# VIVO Y11IW 23
# OPPO PBET00 23
# VIVO_Y51A 23
# HM-I506-TL 23
# CHE-TL00 23
# SAMSUNG_GALAXY-NOTE-3 23
# MI_NOTE_2 23
# HUAWEINXT-AL10 22
# MIX 3 THE PALACE MUSEUM EDITION 22
# ZTE V0721 22
# VIVO Y13I 22
# HUAWEI_MAIMANG-4 22
# SM-G965F 22
# M682Q 22
# COOLPAD 8675-FHD 22
# MI9SE 22
# GIONEE GN5006 22
# CLT TL01 22
# BLN AL20 22
# HONOR HRY-AL00TA 22
# HUAWEI P7-L09 22
# SM-W2018 22
# VIVO_X9S_PLUS_L 22
# ZTE BV0701 22
# OPPOR7S 22
# H9493 22
# REDMI_NOTE_7_PRO 22
# R9SK 22
# ZTE BA603 22
# KOOBEE H9 22
# KOPO L9 22
# NX513J 22
# VIVO%20Y83 22
# M812C 22
# V3MAX 22
# HTC U-3W 21
# OPPO-A77 21
# SM-W2016 21
# ZTE V0900 21
# DOOV L9 21
# KOOBEE K10 21
# VIVO_Y66L 21
# VIVOY79A 21
# VIVO IQOO 21
# MI5SPLUS 21
# VIVO Y17W 21
# X21 21
# SM-G7108V 21
# VIVO+Y66L 21
# HUAWEI SC-UL10 21
# VIVO_Y55A 21
# NEXUS 6 21
# OPPO_R9KM 21
# REDMI-NOTE-4X 21
# ZTE B2015 21
# SUGAR S9 21
# NTS-AL00 21
# COOLPAD 5380CA 21
# NCE AL00 21
# KOPO A1 21
# ATU AL10 21
# SM-G950U 21
# VIVO-X6D 21
# VIVO+Y55 21
# HONOR COL-TL10 21
# S3 21
# N360 21
# VIVO+X6S+A 21
# K10 21
# CLT TL00 20
# OPPO%20A57T 20
# HUAWEI RIO-UL00 20
# HUAWEI C199 20
# ONEPLUS_A3010 20
# VIVO Y19T 20
# HTC D10W 20
# MI4LTE 20
# VIVO Y51N 20
# YAL AL00 20
# H4233 20
# MI 4C 20
# DOOV A8 20
# OPPO_A53M 20
# REDMI+6 20
# A83T 20
# FDR-A03L 20
# HLTE210M 20
# EVA AL00 20
# NX510J 20
# LEZHOU LZ6 20
# HISENSE A2T 20
# H2 20
# CAM AL00 20
# MI_8_LITE 20
# OPPO%20R9%20PLUSM%20A 20
# OPPOA33 20
# C105 20
# A53 20
# BLA-L29 20
# VIVO V1809A 20
# GT-I9508 20
# DUA AL00 20
# POT-TL00A 20
# HL2001 20
# VIVOY66L 20
# C730LW 20
# OPPO+A77T 20
# HUAWEI TIT-CL00 20
# G620-L75 20
# NX535J 20
# KIW AL10 20
# LDN AL20 20
# OPPOA77T 20
# COOLPAD 8675 20
# LENOVO L78032 20
# OPPO_A37T 20
# VIVO+X9L 20
# X6L 20
# SUGAR S20 20
# GOME 2018X38A 20
# 1821-T0 20
# SM701 20
# SM-G9008W 20
# ZTE BA610T 19
# VIVO-Y51A 19
# SOP-S8 19
# LENOVO Z2 19
# CPH1607 19
# COOLPAD A8-930 19
# VIVO_X20PLUS_A 19
# M2+E 19
# OPPO+A33 19
# OPPO PBCM10 19
# SM G9350 19
# M10 19
# LENOVO+L78011 19
# T8 19
# A37T 19
# MAICHAI 19
# VIVO+X9S+L 19
# OPPO A53T 19
# OPPO_R11S_PLUS 19
# X500 19
# H8166 19
# OPPO PAAM00 19
# FIG-TL00 19
# Y55L 19
# GN152 19
# HONOR BKK-TL00 19
# VIVOX9L 19
# I6 19
# X6S 19
# GIONEE F205L 19
# T1-823L 19
# M463C 19
# BAH2-W09 19
# OPPO+R11S+PLUS 19
# XIAOMI REDMI 6 PRO 19
# PE-UL00 19
# OPPO-A59M 19
# OPPO A59T 19
# BOWAY T6 19
# VIVO_Y67 19
# L50T 19
# X20(X9S) 18
# REDMINOTE5A 18
# HISENSE F22M 18
# VIVO%20X7PLUS 18
# VIVO-Y67A 18
# H10 18
# SUGAR Y7 18
# VIVO Y33L 18
# ZTE BV0720T 18
# VIVOY83 18
# ZYVM3 18
# M1_E 18
# VOTO IX20(GT20) 18
# SM-N9508 18
# SUGAR S11 18
# VIVO-X21UD-A 18
# Y55 18
# DRA AL00 18
# NOAIN X9 PRO 18
# SM-J3308 18
# VIVO+Y55L 18
# SAMSUNG SM-G9500 18
# HM 1S 18
# PCDT00 18
# ZTE BA601 18
# HUAWEI_TIT-AL00 18
# VIVO-Y83 18
# VOTO GT07 18
# VIVO-Y55 18
# X9009 18
# VIVO X710F 18
# REDMI-5-PLUS 18
# HUAWEI MLA-TL00 18
# OPPO%20A59M 18
# KOOBEE S301T 18
# PRO+6+PLUS 18
# 4G%2B 18
# MI 2 18
# R8000 18
# CHM CL00 18
# KOOBEE S302M 18
# SM G9730 18
# VIVO+Y71A 18
# LENOVO K50-T5 17
# H100 17
# MIMAX 17
# ONEPLUSA6010 17
# VIVO%20X20 17
# VIVO+X7PLUS 17
# VIVO-Y67 17
# REDMI_4A 17
# VIVO VIVO Z1I 17
# YEPEN 17
# 585P 17
# GT-N7102 17
# CHE1 CL10 17
# ONEPLUS+A3000 17
# GOME S1 17
# OPPO PACT00 17
# 20180208Q 17
# VKY-L29 17
# X9000 17
# MI-MAX-2 17
# MEIZU+E3 17
# HUAWEI VNS AL00 17
# BND TL10 17
# HUAWEI TAG TL00 17
# ZTE C2016 17
# VIVO Y622 17
# E6883 17
# GIONEE F109L 17
# REDMI+NOTE+3 17
# LENOVO A808T 17
# SM G9508 17
# V3 17
# AGS-L09 17
# VIVO_X21A 17
# MI%206X 17
# REDMI+NOTE+5A 17
# LENOVO A938T 17
# OPPO+R11+PLUSKT 17
# SM-G9006V 17
# VIVO VIVO Y83A 17
# OPPO_R9T 17
# AUM AL20 17
# 1707 A01 17
# OPPO+A73T 17
# GN8001L 17
# SM-W2017 17
# OPPOR7SM 17
# OPPO%20A83 17
# REDMINOTE2 17
# ZTE BA602 17
# VIVOY51A 17
# Y66 17
# SAGA A908 17
# LENOVO L78051 17
# OPPOR9PLUSTMA 17
# SM-G960F 17
# OPPO-R9M 16
# MYA AL10 16
# SM-G9308 16
# ZTE C2017 16
# GIONEE_GN5007L 16
# M6-NOTE 16
# V1901T 16
# PRO+7+PLUS 16
# SM C9000 16
# SAGA M8 16
# HMNOTE1LTE 16
# SM-N950U 16
# OPPO_R11ST 16
# POCOPHONE F1 16
# I1 16
# X520 16
# F303 16
# VIVOX21I 16
# ZUK Z1 16
# REDMI+4X 16
# LEX620 16
# VIVO-Y71A 16
# HUAWEI TIT AL00 16
# OPPO-A33 16
# MP1801 16
# OPPO+A79 16
# MODEL 16
# MI%206 16
# VIVO%20X9S%20PLUS 16
# HISENSE F31 16
# OPPO-R11ST 16
# LENOVO K520 16
# VIVO Y35L 16
# VIVO-X21 16
# OPPO PBBT00 16
# PHILIPS S626L 16
# MIX%202 16
# ONEPLUSA5000 16
# HCHM1 16
# OPPO%20A37M 16
# 3005 16
# HONOR YAL-AL00 16
# HWI TL00 16
# JMM-TL10 16
# MI 4W 16
# OUJIA 2019 15
# VIVO+Y79A 15
# MI PAD 4 PLUS 15
# VIVO_V3M_A 15
# REDMI+4A 15
# BLN-TL00 15
# CMR-W09 15
# SM G9750 15
# SM-J7109 15
# MRD TL00 15
# SM-G9608 15
# 1873-A0 15
# VIVO Y11T 15
# ZTE A0620 15
# HMA-L29 15
# ZTE A2020 PRO 15
# COOLPAD 8718 15
# GN9007 15
# AR9 15
# SM-N960F 15
# KOB-W09 15
# SAMSUNG SM-G9550 15
# LYA TL00 15
# GT-N7108 15
# ASUS_X008 15
# MI5 15
# MI%20NOTE%203 15
# GT-I9300 15
# VIVO VIVO X21 15
# GN5001L 15
# MI+NOTE+2 15
# HUAWEI C8816D 15
# OPPOR11PLUSKT 15
# SM-G930F 15
# VIVO V1818A 15
# H7 15
# HISENSE F30 15
# CAM TL00 15
# MI 3C 15
# M3NOTE 15
# VIVO%20X21I 15
# MI-6X 15
# OPPOR9KM 15
# VIVO_Y67A 15
# SM G8750 15
# VIVO+X6D 15
# VIVO X23  MAGIC COLOR 15
# COMIO I2 15
# HTC D820US 15
# MI_MAX_3 15
# ZTE A2019 PRO 15
# DLI TL20 15
# HLTE216T 15
# 20170608S 15
# VIVOY71A 15
# VIVO VIVO Y85 15
# VIVO_X6A 15
# SM N9600 14
# GIONEE+GN5007 14
# SUGAR F11 14
# KNT AL20 14
# CHE2-UL00 14
# NG2 14
# GO T5 14
# ONEPLUSA5010 14
# SM-N900 14
# G8232 14
# HISENSE A2 14
# NOAIN X9V 14
# 4X 14
# CHANGHONGS18 14
# R9T 14
# LDN-AL10 14
# PRO+7-S 14
# VIVO Y81S 14
# GIONEE_S10C 14
# VIVO X6S 14
# SM-A3050 14
# M355 14
# VIVOX6SA 14
# C105-6 14
# VIVO+Y71 14
# HUAWEI LYA-TL00 14
# M5%20NOTE 14
# COOLPAD A8-831 14
# 8848 M5 14
# G8441 14
# HUAWEI MLA-UL00 14
# PAR-TL20 14
# VIVO+V3MAX+A 14
# LE_X620 14
# V9 14
# VIVO+Y27 14
# HTCONE 14
# X9PLUS 14
# OPPOA73T 14
# GIONEE F205 14
# EDI AL10 14
# K350T 14
# C603 14
# HDL-W09 14
# OPPOR7 14
# Y66L 14
# ATH-CL00 14
# KOOBEE F1 14
# S10 14
# SM-G935F 14
# HISENSE M20-T 14
# ZTE_V0840 14
# LE X625 14
# SAGA M7 14
# HY-002 14
# VIVO%20X9S 14
# X20 14
# MI-8 14
# LETVX500 14
# VIVO+Y67 14
# OPPO PBFM00 14
# EVR-TL00 14
# HLTE700T 14
# MEIZUS6 13
# MI-5X 13
# HUAWEI MHA-AL00 13
# F100B 13
# VIVO_X6D 13
# SUGAR C9 13
# OPPO-R9TM 13
# 4A 13
# KINGSUN-F16 13
# NX617J 13
# HM NOTE 1TD 13
# OPPO-R11S-PLUS 13
# OPPOR11SPLUST 13
# HONOR HRY-AL00T 13
# ZTE BA611C 13
# A51KC 13
# HLTE510M 13
# VIVO_X5S_L 13
# HUAWEI__HUAWEI__ELE-AL00 13
# DOOV_V18 13
# V5 13
# G621-TL00 13
# REDMI+S2 13
# VIVO-X7 13
# X6PLUS 13
# VIVO X1ST 13
# T1-A23L 13
# R11S PLUS 13
# T1 13
# VIVO V1813T 13
# M688C 13
# HUAWEI G750-T01 13
# CPH1701 13
# SM C7000 13
# 1801 A01 13
# VIVOX20PLUSA 13
# DOOV L5M 13
# XIAOMI_REDMI-2 13
# MINOTELTE 13
# SUGAR F7 13
# OPPO-A33M 13
# COOLPAD Y91-921 13
# XT1635-03 13
# OPPO+R7SM 13
# ZTE C880A 13
# 20181225 13
# DRA-TL00 13
# HISENSE_F23 13
# SM-G9009D 13
# E6683 13
# ANE-LX2 13
# SM-G955U 13
# 520 13
# VIVO+Y83 13
# V188S 13
# MAX3 13
# TCL 580 13
# VIE AL10 13
# KOOBEE S12 12
# KOOBEE A3 12
# SM-G9009W 12
# GN9000L 12
# VIVO Y55N 12
# ONEPLUS_A3000 12
# CPH1719 12
# 20151209T 12
# YT886-12 12
# XT1789-05 12
# SM-G9287 12
# VIVO%20X9PLUS 12
# REDMI3 12
# R9ST 12
# VIVO Y93 STANDARD 12
# SM-N9150 12
# NOKIA X71 12
# VIVO-X7PLUS 12
# LENOVO P70-T 12
# OPPO%20A73 12
# ZTE C880U 12
# C8817D 12
# VIVO_X9PLUS_L 12
# LENOVO A2860 12
# OPPO+R7 12
# OPPO-A83T 12
# PCT TL10 12
# GIONEE S11L 12
# HTC U-1W 12
# OPPO+A79K 12
# VIVO_Y75A 12
# LEPHONE V8 12
# SM-G965U1 12
# H9 12
# BAH-AL00 12
# VIVO+X21I 12
# X5MAX+ 12
# REDMI_6A 12
# VIVO%20Z1 12
# K3DX-V5G 12
# VIVO-Y55L 12
# VIVOX9SPLUS 12
# KOOBEE S506M 12
# OPPO%20R11S%20PLUS 12
# KOPO K11 12
# HUAWEI CLT-TL00 12
# VIVO X27 12
# X9070 12
# I4293 12
# VIVO_Y23L 12
# LETVX501 12
# OPPO_A83 12
# OPPOR7SPLUS 12
# VIVO-Y23L 12
# SUGAR C11 12
# HTC D820T 12
# MEIZU+M6 12
# HUAWEI ELE-TL00 12
# VIVO%20X6D 12
# Y26 12
# REDMI5 12
# X5M 12
# ELE TL00 12
# LINGWIN 9 (X) 12
# R11 PLUS 12
# ALP-L29 12
# Y35A 12
# PRA TL10 12
# SHT-AL09 12
# KOPO T9 12
# JKM-LX2 12
# X8 12
# 20180102Q 12
# VIVO-Z1I 12
# FS8016 12
# M1-E 12
# C1001 12
# 2013022 12
# M6_NOTE 11
# VIVO+X3L 11
# SM-A5108 11
# N1 11
# GO T6 11
# 7PLUS 11
# H30-U10 11
# VIVO-X20 11
# LYA AL00P 11
# HUAWEI_ENJOY-5S 11
# MI+8+EXPLORER+EDITION 11
# OPPO-R7 11
# VIVO%20X9L 11
# GIONEE_S10 11
# BIHEE A11 11
# COOLPAD Y72-921 11
# XT1941-2 11
# MP1711 11
# HUAWEI C8816 11
# VIVONEXS 11
# VIVO_X3L 11
# LEPHONE T10A 11
# TCL P590L 11
# CM810 11
# SM-G7108 11
# LA-S35 11
# R2010 11
# VIVO_X20PLUS 11
# HUAWEI ALP-AL00 11
# XIAOMI MI 9 11
# X1 11
# OPPO-R7S 11
# M681C 11
# SM-A730F 11
# PLK TL01H 11
# VIVO%20V3MAX%20A 11
# ZTE A2018 11
# REDMI_NOTE_5 11
# Y31 11
# OPPO+R9SKT 11
# GT-I9158V 11
# ARE-TL00 11
# MEITU M4 11
# GM1911 11
# REDMI K20 11
# HUAWEI TRT-TL10A 11
# CLT-AL00L 11
# VIVO-X6S-A 11
# VIVO_XPLAY6 11
# COOLPAD 9190L 11
# UNNO P8 11
# R830S 11
# HLTE213M 11
# MZ-M6 NOTE 11
# MEIZU_M6 11
# PRO 11
# W900S 11
# LEPHONE T23 11
# BLN TL10 11
# 16THPLUS 11
# OPPO-R9ST 11
# BOWAY U11 11
# A77 11
# JDN2-W09 11
# BKL AL00 11
# VIVO VIVO X21UD A 11
# VIVO_Y83A 11
# REDMI7 11
# JD-PLUS 11
# LEX820 11
# OPPO PADT00 11
# K-TOUCH X21 11
# OPPO%20A83T 11
# MRD-TL00 11
# LYA-L09 11
# HUAWEI%20MLA-AL10 11
# VIVOX6D 11
# LDN-TL10 11
# AGS2-W09HN 11
# VIVO-X9S 11
# VIVO+Y66I+A 11
# HUAWEI-MLA-AL10 11
# SM-G950U1 11
# VIVO Y93S 11
# VIVO-Y71 11
# R827T 11
# M1+E 11
# MI%208%20UD 11
# VIVO_X21UD_A 10
# VTR-L29 10
# FIG AL00 10
# OPPO-R7SM 10
# NOKIAX6 10
# HUAWEI ARS-TL00 10
# CPH1823 10
# SAMSUNG_GALAXY-S6 10
# X20A 10
# OPPO-A37T 10
# OPPO%20R9ST 10
# OPPO_A77 10
# G115 10
# VIVOX9SL 10
# ONEPLUS_A5000 10
# HUAWEI CLT-L29 10
# VIVO-Y66L 10
# HAIPAINOBLE S19 10
# R829T 10
# YQ605 10
# VIVO%20X9I 10
# LENOVO A788T 10
# 20180101M 10
# KOOBEE S206M 10
# UNNO E5 10
# HUAWEIG520-5000 10
# ZUK Z2151 10
# VIVO+Y35 10
# SM-G5309W 10
# KONKA S1 10
# SM-G960W 10
# NX512J 10
# KNT UL10 10
# HUAWEI RIO-CL00 10
# F8332 10
# NOKIA+X6 10
# MIX%203 10
# OPPO%20R7SM 10
# REDMI3S 10
# L55T 10
# 1872-A0 10
# XT1581 10
# XT1942 1 10
# CPN AL00 10
# H30-C00 10
# XT1710-08 10
# 1807 A01 10
# F301 10
# OPPO+R7S 10
# OPPO PBBM30 10
# VIVOY75A 10
# HUAWEI CRR-UL20 10
# HTC E9PW 10
# LON-L29 10
# Y13IL 10
# LON AL00 10
# VIVO%20X20PLUS%20A 10
# YU_FLY_F9 10
# CPH1831 10
# VIVOY67L 10
# REDMI_NOTE_5A 10
# KT-101-A 10
# VIVO X27 8G+128G 10
# FYT6025 10
# DOOV L525 10
# ANE-LX1 10
# HTC D820U 10
# 2014112 10
# K TOUCH X21 10
# M9S 10
# VIVO+Y13L 10
# VIVO+Y67L 10
# MAX3(X23) 10
# LT580 10
# REDMI-NOTE-3 10
# LE X822 10
# Q21 10
# SM A3050 10
# XT1650-05 10
# HTCT328T 10
# LENOVO PB2-670N 10
# BBB100-4 10
# BOWAY_X6 10
# T07 10
# VIVO X5F 10
# BEST_SONNY_LT511 10
# 2 10
# GN9008 10
# ZUG_5S_Q 10
# IVVI I3-01 10
# OPPO%20A77 10
# LENOVO A5860 10
# NEXUS 5 10
# U51 10
# SM-G977N 10
# R821T 10
# OPPOA33M 10
# REDMI-6-PRO 10
# PIONEERW8 10
# GEM-703LT 10
# F103S 10
# BG2-W09 9
# E-MIRROR 9
# REDMI6 9
# OPPO+A79T 9
# CAM TL00H 9
# HUAWEI%20NXT-AL10 9
# REDMI-3S 9
# OPPO PBFT00 9
# MAX3(R17) 9
# OPPOA59ST 9
# SM-T555C 9
# A37F 9
# A73T 9
# LENOVO K50-T3S 9
# VIVO+X6PLUS+D 9
# VIVO-X9L 9
# REDMIS2 9
# REDMI4 8
# SM-G5108Q 8
# PLK AL10 8
# HUAWEI SHT-W09 8
# MI5S 8
# KOOBEE S9Q 8
# GOME 2016M25A 8
# HHT6A 8
# OPPOA79T 8
# OPPO-A73 8
# KOOBEE S9 8
# HUAWEI_ALE-CL00 8
# GOME 2017X05A 8
# TNY-TL00 8
# SM-A3000 8
# MI+5C 8
# LYA-L0C 8
# RAMOS MOS1MAX 8
# Y79A 8
# VIVO%20XPLAY5A 8
# KOB-L09 8
# SM-G7109 8
# LENOVO P2C72 8
# SM C5000 8
# PHILIPS X596 8
# ATH-TL00H 8
# C311 8
# BAIDUZHE 8
# REDMIK20PRO 8
# LZ7 8
# VIVO VIVO Y83 8
# HUAWEI+VNS-AL00 8
# HTC 8088 8
# SM-C7018 8
# REDMI-4A 8
# VIVOY51 8
# OPPO PBCT10 8
# DOOV A11 8
# REDMI6A 8
# HUAWEI CAZ TL20 8
# HTC D626W 8
# SM-N9208 8
# HM2A 8
# GIONEE_F6 8
# SM-G900F 8
# DOOV V11 8
# LEPHONE T6+V 8
# HTC M8SW 8
# PRO+7-H 8
# QUY Q1S 8
# LENOVO%20L78011 8
# M3-NOTE 8
# ONEPLUS_A5010 8
# VIVO%20X21UD 8
# HUAWEIMLA-AL10 8
# ASUS_X00GD 8
# MI%205X 8
# YCT11 8
# LENOVO A3910T30 8
# X6PLUS D 8
# VIVO VIVO NEX A 8
# PHILIPS X598 8
# HUAWEI CLT-TL01 8
# M3+NOTE 8
# OPPOR11PLUSK 8
# HUAWEI%20CAZ-AL10 8
# REDMI+6A 8
# X 8
# DOOV A10 8
# V21-X 8
# OPPO+A53 8
# VIVO-X9PLUS 8
# SAST SA9 8
# LETV_X501 8
# VIVO-Y67L 8
# Y27 8
# RNE-L22 8
# LE+X620 8
# VIVOY66IA 8
# ANDROID 8
# VIVO_NEX_A 8
# HMNOTE1S 8
# LENOVO L38011 8
# HUAWEI HWI-AL00 8
# SCH-I739 8
# VIVO_Y27 8
# F9 8
# VIVO%20X9S%20PLUS%20L 8
# VIVO X5MAX 8
# DAZEN 6PLUS 8
# SM G955N 8
# NEXUS 4 8
# X-APPLE 8
# Y685Q 8
# OPPO_R11_PLUS 8
# YUSUN A8 8
# NX507J 8
# SM-W2015 8
# VIVO+X9S+PLUS 8
# SM-T705C 8
# OPPO+A53M 8
# A1006 8
# MI%205S%20PLUS 8
# KOOBEE M9 PLUS 8
# HONOR ARE-TL00 8
# MI_9_SE 8
# OPPO+A37T 8
# VIVO_Y51T_L 8
# ZTE BA910T 8
# X25 8
# HUAWEI_MT-7 8
# HLA NOTE1-L 8
# HUAWEI_CAZ-TL20 8
# LENOVO A3900 8
# HONOR CAM-AL00 8
# YEECHUI S 8
# HUAWEI NXT TL00 8
# BF T19 8
# AGM X3 8
# V1 8
# DOOV A12 8
# I9 8
# VIVO%20Y75A 8
# E100 8
# OPPOR9SKT 8
# E6853 8
# HONOR COR-TL10 8
# VTR-L09 8
# LINGYING A6 7
# REDMI4A 7
# 1713 A01 7
# P23(Z9) 7
# GM2017D07A 7
# OPPOA53M 7
# K-TOUCH K6 7
# KOOMII-K19 7
# VIVO NEX DUAL DISPLAY 7
# E18 7
# MI_9 7
# OPPO-R11-PLUSK 7
# SM-N910U 7
# XT1924-9 7
# COOLPAD Y82-820 7
# SM-C9008 7
# VCE-L22 7
# IVVI SS1-01 7
# LENOVO S898T 7
# 1505 A01 7
# LEPHONE W9+ 7
# PRO7PLUS 7
# IVVI F1S 7
# HISENSE E76MINIM 7
# MYTEL 7
# HTC D820TS 7
# PRO+6S 7
# GIONEEM7 7
# W13 7
# M2_NOTE 7
# M8 7
# REDMI%20NOTE%204X 7
# GEZI 7
# ASUS_X002 7
# HISENSE M30T 7
# SM-C7108 7
# HUAGAN HT6 6
# SA 8 6
# HUAWEIC8813 6
# M2-NOTE 6
# LENOVO Z90-7 6
# HUAWEI HUAWEI MLA-AL10 6
# GO T3 6
# HUAWEI FLA-AL20 6
# VIVO+X6A 6
# K-TOUCH_X11 6
# MX7 6
# COOLPAD Y75 6
# 20180111S 6
# VIVO+V3 6
# AGM X1 6
# FIG TL10 6
# ATH AL00 6
# X30 6
# X5PRO 6
# SCH-N719 6
# HTC 2Q4D200 6
# ONE E1001 6
# HTC X9U 6
# VIVO X27 8G+128G版 6
# SUN001 6
# REDMI%20NOTE%205 6
# H5 6
# MEIZU-S6 6
# XIAOMI_MI-4 6
# SAMSUNG SM-N9600 6
# VIVO%20Y51A 6
# V3M 6
# HWV32 6
# KOOBEE S11 6
# M5000 6
# GN9000 6
# GT-I9507V 6
# REDMI%205%20PLUS 6
# GT-N7105 6
# HISENSE E77M 6
# OPPO PCAM00 6
# HUAWEI TRT-AL00A 6
# OPPO+A79KT 6
# VIVO-NEX-A 6
# MINOTE2 6
# GM-T1 6
# HUAWEI MT7 TL10 6
# VIVO 1716 6
# OPPO+R11S+PLUST 6
# LENOVO A820T 6
# MYA TL10 6
# BAC-L22 6
# U3 6
# H1-4G 6
# SOAP R11 LITE 6
# NOKIA+7+PLUS 6
# ASUS_Z012DE 6
# HUAWEI P7-L00 6
# A77T 6
# OPPO-A73T 6
# PLUST 6
# CLT-L09 6
# KOOBEE F2 6
# LE_X820 6
# SM G955F 6
# HTC D728W 6
# MI-NOTE-3 6
# MI-8-SE 6
# DOOV L1 6
# LE_X528 6
# NX505J 6
# M353 6
# SM A7050 6
# PLE 703L 6
# 4 6
# BOWAY U15 6
# HUAWEI C8815 6
# MI MIX 3 5G 6
# VIVO+Y53 6
# XT1799-2 6
# AE Q3 6
# NCE TL10 6
# VIVO_Y28L 6
# HONOR H30-L01M 6
# OPPOA53 6
# MAX 6
# COOLPAD 5360 6
# S562Z 6
# MI9 SE BROWN EDITION 6
# HUAWEI VKY-AL00 6
# HDN-W09 6
# SM A6058 6
# VIVO%20Y67A 6
# VIVO%20NEX 6
# ZL10 6
# LE_X621 6
# OPPOR9SPLUST 6
# SHOWN P2 6
# EVA-CL00 6
# ASUS_Z010DA 6
# DOOV A15 6
# VIVO 1723 6
# VIVO-X21I 6
# KOOBEE M7Q 6
# ZTE Q806T 6
# D3 6
# OPPO PBBT30 6
# ZUK+Z2131 6
# NOTE4X 6
# HTC M8ST 6
# HUAWEI GRA UL10 6
# HUAWEI__HUAWEI__CLT-AL00 6
# SM-T815C 6
# LENOVO P770 6
# REDMI+3S 6
# SKR A0 6
# PRO 7 S 6
# REDMI%20NOTE%207%20PRO 6
# TA 1000 6
# BBF100-4 6
# REDMI-NOTE-4 6
# HM NOTE 1LTEW 6
# VIVO_Z1 6
# SM-T710 6
# SM-A6058 6
# SM T715C 6
# ZTE C880S 6
# SM-G935S 6
# MI PAD 3 6
# ZTE C880D 6
# 20170829M 6
# DOOV V15 6
# DOOV L925 6
# ATU TL10 6
# VIVO_X5L 6
# LDN-LX2 6
# 2A 6
# D888 6
# H18 6
# GO 50023 6
# COOLPAD B770S 6
# MI_5 6
# MIPLAY 6
# MI_9_TRANSPARENT_EDITION 6
# LM-G710 6
# K-TOUCH X9 6
# HL3001 6
# 2019 6
# 98(M1E4) 6
# Y01(YP01) 6
# P8MAX 6
# HUAWEI_GRA-UL10 6
# GIONEE_M7 6
# HUAWEI TAG-CL00 6
# X5 6
# COOLPAD 8690_T00 6
# MI-5 6
# HUAWEI VTR-AL00 6
# GT-I9300I 6
# ZTE A606 6
# OUJIA S20 6
# SUGAR Y11 6
# GT-I9502 6
# HUAWEI MAR-TL00 6
# C105-8 6
# SM C7100 6
# VIVO+X710L 6
# VIVO_X21I_A 6
# LINGWIN 6
# LENOVO A2580 6
# M1_METAL 6
# R17S 6
# MEIZU_S6 6
# HISENSE_F22 6
# SM-G960U 6
# D51732 6
# VIVOY55A 6
# MI_5C 6
# AGS2-AL00 6
# M3+MAX 6
# LENOVO K32C36 6
# MI%20MAX%202 6
# HUAWEI CAZ TL10 6
# ASUS_X00QD 6
# VIVO-X5S-L 6
# XIAOMI REDMI NOTE 7 PRO 6
# KING 7S 6
# KOOBEE S301 6
# ZTE Q802T 6
# 1100 6
# HUAWEI Y635-TL00 6
# TIANDOU 6
# ZTE V1000 6
# HUAWEI_M2-803L 6
# LEPHONE T20 6
# HTC U11 6
# Y33 6
# LENOVO TB-8703N 6
# M2NOTE 6
# SAMSUNG_GALAXY-J5 6
# DOOV V18 6
# CENXIN S17 6
# VIVO_Y55L 6
# MEIZU-M6 6
# GIONEE-S10CL 6
# COOLPAD Y90 6
# R2 6
# SCL AL00 6
# LENOVO K51C78 6
# A107 6
# NG3 6
# MI A2 6
# SM-J700F 6
# VIVO+Y28L 5
# M1+NOTE 5
# SM-A750GN 5
# REDMI-7 5
# A8 5
# V15(V18) 5
# A7 5
# SM-G930K 5
# COOLPAD Y71-511 5
# ASUS_Z01FD 5
# A-WATCH 5
# R11 DIM 5
# PHILIPS_V787 5
# WAS-LX2 5
# HUAWEI SLA-TL10 5
# VIVO+Y35A 5
# 8298-A01 5
# SCH-I959 5
# VIVO-X6PLUS-D 5
# L3 5
# HISENSE E9 5
# 4LTE 5
# HTC+U-3W 5
# LE+X528 5
# XIAOMI_REDMI-1S 5
# MI-4LTE 5
# OX2 5
# 6PLUS 5
# KT107 5
# SM N9508 5
# HISENSE E51-M 5
# CPH1835 5
# SM-G610F 5
# X21(OX2) 5
# DOOV_L8_PLUS 5
# ZTE BA602T 5
# SM G955U 5
# SAMSUNG SCH-I889 5
# LPHONE8 5
# VOTO GT2017 5
# OWWO A8 5
# GIONEE_S10L 5
# MEIZUM6 5
# Q7 5
# VIVO-Y66I 5
# M5L 5
# VIVOY71 5
# MI%205S 5
# VIVO%20Y55L 5
# VIVO-Y75 5
# M040 5
# TA 1054 5
# GIONEES10C 5
# SOP-S7 5
# VIVO%20Y23L 5
# REDMI-4X 5
# VIVOY66I 5
# HUAWEI_TIT-CL00 5
# OPPO-A79 5
# 521 5
# ASUS T00G 5
# H60 L01 5
# PRO_5 5
# K-TOUCH_X9 5
# HUAWEI__HUAWEI__VOG-AL10 5
# SM-J701F 5
# M578CE 5
# VIVO-Y66I-A 5
# C106-6 5
# GT-I9308I 5
# CMR-AL09 5
# LGUS992 5
# NOKIA NOKIA X6 5
# VIVO+V3M+A 5
# XT1943-1 5
# OPPO+R7SPLUS 5
# HONOR STF-AL00 5
# VK X PLUS 5
# REDMI-NOTE-5 5
# P10 5
# SM-G3608 5
# SM-A530F 5
# LENOVO PB1-770N 5
# JKOPO F1 5
# SM G6000 5
# LENOVO A368T 5
# LENOVO X2-TO 5
# MEIZU 5
# SAGA M6 5
# CPH1969 5
# HUAWEI TIT CL10 5
# DOOV L5PRO 5
# OPPO-A53 5
# XIAOMI MI 8 UD 5
# VIVO%20Y66L 5
# BEST SONNY LT681 5
# 1809 A01 5
# DOOV L1M 5
# SM-N960U 5
# R9SKT 5
# QUALCOMM SNAPDRAGON 5
# AGS2-W09 5
# BGO-DL09 5
# TETC-F5 5
# SM G950F 5
# CPH1819 5
# BF T66 5
# HUAWEI_P8MAX 5
# INE LX2 5
# VIVO_Y35A 5
# VIVO Y81 5
# H3000 5
# HONOR PCT-TL10 5
# VIVO%20Y55 5
# X6SPLUS 5
# EYU T5S 5
# M460A 5
# SAMSUNG_GALAXY-A9 5
# ELE-L29 5
# BOWAY U12 5
# HUAWEI_CAZ-TL10 5
# X5S 5
# DAZEN X7 5
# HONORH30-L01 5
# MEDIAPAD 5
# XPLAY6 5
# REDMI%204X 5
# PRO_6 5
# C106 9 5
# SAMSUNG_GALAXY-TAB-S 5
# ONEPLUS ONEPLUS A6000 5
# P024 5
# VIVO_X5MAX+ 5
# HUAWEI LON-AL00 5
# PLAYER 5
# REDMI+5 5
# MOTO Z (2) 5
# VIVO V1818CA 5
# H8 5
# HILARY H2 5
# VIVO_V3 5
# HTCX920E 5
# 5X 5
# OPPO%20A73T 5
# LGM-V300L 5
# LOVME-T23 5
# OUJIA 2018-S10MAX 5
# CHANGHONGC08 5
# LEPHONE T26 5
# OPPO%20R7 5
# NEOLIX DB-A-C-1 5
# U7 5
# VIVO%20Y79A 5
# VIVO_X6PLUS_A 5
# L36H 5
# NEOLIX 1-C-P 5
# LEBEST_R11 5
# E6653 5
# N6 5
# VIVO-V3M-A 5
# SKW A0 5
# 4G_VOLTE 5
# C687 5
# PRO6PLUS 5
# HUAWEI NCE-AL10 5
# SM N9006 5
# OYSIN R15 5
# OPPO PCAM10 5
# OPPOA37T 5
# HLJ6 5
# X7L 5
# ZTE Q529T 5
# MZ-M5 NOTE 5
# GIONEE_M7L 5
# AOLEDIOR 5
# 16 5
# HONOR DUK-AL20 5
# VIVOY75 5
# SM N9009 5
# PP5200 5
# HTCM8ST 5
# LEX728 5
# SM-T805C 5
# EYU T5 5
# YT886-10 5
# DOOV L5 5
# REDMI-6 5
# GIONEE+S10C 5
# D6653 5
# VIVO V1818CT 5
# RNE-L21 5
# A30 5
# XT1925-10 5
# LEPHONE T2V 5
# SM-A530N 5
# R819T 5
# ZTE-A0616 5
# COOLPAD 5270 5
# HUAWEIG730-T00 5
# LENOVO X3C70 5
# GOME_2018X38A 5
# PROTRULY V10S 5
# SK3-01 5
# CHANGHONGA600 5
# VIVO Z3I 5
# TCL 520 5
# NOAIN T01 5
# H60 L03 5
# S6000 5
# ASUS_Z01RD 5
# LENOVO A320T 5
# SM-N960U1 5
# M2_E 5
# OPPO PAFM00 5
# HUAWEI MT7 TL00 5
# ALP TL00 5
# KIW CL00 5
# S03 5
# SM-G965W 5
# G01111 5
# OPPO_A59ST 5
# MEITU V4 5
# H9S 5
# HUAWEI_HONOR-4C 5
# XIAOMI_REDMI-NOTE-1 5
# SM-J3119S 5
# MLLED MAX3 5
# LENOVO S890 5
# VIVO V1821A 5
# T10 5
# HTC 802W 5
# LEPHONE T708V 5
# CAM UL00 5
# M3%20NOTE 5
# F88 5
# SM-T355C 5
# 6S 5
# SM G9700 5
# XIAOMI_NOTE 5
# HUAWEI CPN-W09 5
# 1803 A01 5
# VIVO_X6PLUS_D 5
# MAR-LX2 5
# BLA-A09 5
# HUAWEI-CAZ-AL10 5
# SM-T311 5
# VIVO V1732T 5
# CPH1877 5
# BF M10 5
# TCL M2M 5
# V8 5
# X3L 5
# P32A6 5
# IVVI K5 5
# HONOR FRD-AL10 5
# Z5Q 5
# SM-G8508S 4
# MIYU 8X 4
# MBI I7 4
# MI%20MAX 4
# T9 4
# KOOBEE F2 PLUS 4
# HUAWEI MLA AL00 4
# M2+NOTE 4
# COOLPAD M3 4
# ZTE+BA520 4
# MIX%202S 4
# SUGAR C21 4
# VIVOV3MA 4
# VIVO Z1 YOUTH 4
# VIVO%20Y35 4
# M-A5 4
# K1 4
# H6 4
# LA-S9 4
# DOOV A15S 4
# ECETD ET900 4
# G6PLUS 4
# P1S 4
# LEPHONE T708 4
# MI_MAX 4
# OUJIA_2019 4
# C685 4
# V185 4
# NOKIA%20X6 4
# N958ST 4
# %2522PACM00%2522 4
# SM A9000 4
# HTC D816D 4
# ONEPLUS_A6000 4
# SM-G965U 4
# N5110 4
# GIONEE+S10CL 4
# BEST SONNY LT529 4
# EWG XS MAX 4
# ZTEBV0730 4
# X2 SE 4
# C313 4
# H60-L12 4
# SUGAR Y15 4
# R11SPLUS 4
# TETC-V1 4
# 16X 4
# SM-G930L 4
# SM-J111F 4
# MIX 2S EMERALD EDITION 4
# 20 4
# VOG TL00 4
# KEPLER 4
# HTC 2Q4R400 4
# FRD DL00 4
# OPPO%20A77T 4
# OPPO_R7ST 4
# KOOBEE S509 4
# VIVO-X5V 4
# MI%205 4
# HTC+2Q4D200 4
# VIVO V1831A 4
# GIONEE_S10B 4
# ASUS_Z012DA 4
# REDMI-4 4
# HUAWEI+CAZ-TL20 4
# MEDIAPAD10 4
# X9079 4
# NOKIA7PLUS 4
# SM-J600G 4
# MI%208%20EXPLORER%20EDITION 4
# GIONEES10L 4
# C107-9 4
# BND-L34 4
# VIVO_Y29L 4
# SAMSUNG_GALAXY-TAB-A 4
# MI9TRANSPARENTEDITION 4
# ZUK+Z2121 4
# HUAWEI+TAG-AL00 4
# HUAWEI TRT-AL00 4
# LENOVO S968T 4
# TNY TL00 4
# NOKIA+X7 4
# SM G9608 4
# CPH1609 4
# OPPOPADM00 4
# ZTE Q7 4
# PAR-LX9 4
# LENOVO P780 4
# HISENSE E20T 4
# M2%20E 4
# HTC M8SD 4
# GIONEEM7L 4
# HUAWEI-NXT-AL10 4
# LENOVO S850T 4
# OPPO%20A79 4
# D9 4
# MZ-M3 NOTE 4
# VIVO_X5PRO_D 4
# A79T 4
# VIVO-X5M 4
# KOOBEE_H9 4
# REDMI%20NOTE%205A 4
# XSHITOU P7 4
# VIVO_Y79A 4
# KT101-A 4
# REDMI%204A 4
# IVVI V2 4
# MC002CT 4
# HUAWEI DUB-AL00A 4
# GT-I9158 4
# S100 4
# W900 4
# ZUG 5S Q 4
# SUGAR C7 4
# HISENSE K1 4
# DMZ S3 4
# NEM TL00H 4
# ZTE Q519T 4
# HUAWEI+C8816D 4
# G123 4
# VIVOXPLAY6 4
# VIVO PD1728 4
# BF_A500 4
# ONEPLUS-A6010 4
# HISENSE_E77 4
# NOAIN X9 PLUS 4
# SM-G960U1 4
# VIVOY55 4
# S105 4
# SM-N920K 4
# SM N950N 4
# GO C2 4
# HISENSE+F23 4
# XT1085 4
# CHANGHONGS08 4
# VIVO+X5L 4
# WAS TL10 4
# SM G9200 4
# HTC M8ET 4
# HUAWEI_TIT-CL10 4
# MI-9-TRANSPARENT-EDITION 4
# MI 2A 4
# D8 4
# HUAWEI PIC-AL00 4
# ON 4
# E6533 4
# A79 4
# REDMI NOTE 6 PRO 4
# N910 4
# R15 4
# VIVO_X6SPLUS_D 4
# SCL TL00 4
# COOLPAD 8297 4
# VIVO-Y51T-L 4
# M3MAX 4
# HUAWEI G628-TL00 4
# COMIO X9 4
# A37FW 4
# HUAWEI G6-C00 4
# S108 4
# DOOV A3 4
# SOP-S9 4
# VIVO+X5PRO+D 4
# KT107H 4
# HTC 802T 4
# VIVO X5M L 4
# QK-6385T 4
# CHE2 TL00M 4
# M1E 4
# Q101 4
# A900 4
# HUAWEI_C199 4
# REDMI+7 4
# REDMI-5 4
# ASUS_Z011D 4
# XIAOMI MI 9 SE 4
# HLTE720T 4
# VIVO-X3L 4
# NEXUS 5X 4
# DSL C3 4
# HUAWEI BAH-W09 4
# VIVO V1829A 4
# LOVME-T21 4
# SM-P601 4
# ZTE 4
# MI%209%20SE 4
# GIONEEF6 4
# HLTE316T 4
# GIONEE_GN5006 4
# OUJIA 2019 MIX 4
# T6 4
# N09 4
# VIVO+Y31 4
# KOPO L1 4
# SAMSUNG_GALAXY-A8 4
# VIVO%20X9S%20L 4
# READBOY_G550A 4
# LENOVOL78011 4
# VIVO X21S 4
# SM-J730GM 4
# LAABOO V12 4
# RAMOS R9 4
# SAMSUNG_GALAXY-NOTE-4 4
# NOAIN X19 4
# SM-T810 4
# HUAWEI CLT-AL00L 4
# VIVO%20Y66I%20A 4
# SOP-N1 4
# LENOVO K52T38 4
# VIVO+X7L 4
# ZTE_BA611T 4
# AGS2-AL00HN 4
# SM-G3812 4
# HTC 4
# LENOVO TAB 2 A10-70LC 4
# ZYVM2 4
# LEPHONE A7+ 4
# F3 4
# PIC TL00 4
# HUAWEI CRR UL00 4
# COOLPAD 5367 4
# OPPOPBEM00 4
# HOL-T00 4
# AGS-W09 4
# X9S 4
# K10PLUS 4
# ONEPLUS A6013 4
# HUAWEI_P7 4
# E5823 4
# VIVO-X9S-PLUS-L 4
# Y37A 4
# VIVO_X5MAX 4
# IVVI V1M 4
# GIONEES10 4
# Y923 4
# LENOVO S938T 4
# LM-G710N 4
# LENOVO A3910E70 4
# HUAWEIMT7-CL00 4
# 20170605Q 4
# PRO_6_PLUS 4
# IVVI I3P-02 4
# SM-G935L 4
# SM G9250 4
# LENOVOA3000-H 4
# LENOVO A2020A40 4
# MEITU M4S 4
# KOOBEE_M9_PLUS 4
# FIG-LA1 4
# S7 4
# TA-1052 4
# VIVO_Y37 4
# MI-MAX 4
# KIW TL00 4
# HUAWEI SLA-AL00 4
# GIONEE-S10C 4
# VIVO-Y35 4
# LEPHONE T21 4
# VPHONE 4
# LENOVO A2800-D 4
# GOME 2018M29A 4
# HLJ6P 4
# SAMSUNG GT-S7272C 4
# LEPHONE W9 4
# EYU T3 4
# MINOTEPRO 4
# HUAWEI NXT DL00 4
# T101 4
# T805S 4
# XT1570 4
# BIRD LT02 4
# X909T 4
# HUAWEI VIE-AL10 4
# LAABOO V3 4
# COMIO X11 4
# COOLPAD S6-NT1 4
# E12 4
# LENOVO S920 4
# LE_X520 4
# LENOVO P1C58 4
# STF TL10 4
# CPH1871 4
# PIXEL 4
# K-TOUCH X11 4
# Q10 4
# SM G9009D 4
# VIVOX6PLUSA 4
# VIVO 1725 4
# AE G20 4
# CLT AL00L 4
# REDMI-5A 4
# SM-G975F 4
# Q8910 4
# ZTEV0840 4
# METAL 4
# F8132 4
# HONOR PLK-AL10 4
# I8 4
# IVVI V3-T 4
# CHANGHONGS16 4
# INE-LX1 4
# VOLTE 4
# REDMI-3X 4
# S5 4
# ONEPLUSA3010 4
# REDMI%207 4
# CHE TL00 4
# A53T 4
# HUAWEI+TIT-TL00 4
# GIONEE+GN5007L 4
# %2522MHA-AL00%2522 4
# U707T 4
# NOKIA_X6 4
# A33T 4
# LG-F700L 4
# PCDT10 4
# LG-US998 4
# VIVO%20Y55A 4
# HTC M9PT 4
# PIONEER C1 4
# K6 4
# 8848 M4 4
# MI-ONE PLUS 4
# OPPO+R9KM 4
# K-TOUCH_X21 4
# VIVO-Y27 4
# HWV31 4
# COOLPAD 5951 4
# VKY-L09 4
# LDN TL20 4
# HTC D610T 4
# GIONEE GN5006L 4
# ZTE A0722 4
# ZTE Q529C 4
# LENOVO A5800-D 4
# HUAGAN H6 4
# VIVO_Y53 4
# GM1913 4
# M19 4
# VIVO%20Y31A 4
# KINGSUN-F70 4
# HLJS6 4
# BKL TL10 4
# VIVO_X5PRO_V 4
# R831T 4
# 20160526Q 4
# LA-S11 4
# SM-A920F 4
# EP720D 4
# I7S 4
# VIVO_Y37A 4
# VIVO+Y75S 4
# SUGAR F7 MINI 3
# EVA-L29 3
# XIAOMI REDMI K20 PRO 3
# MEDIAPAD 10 3
# GO T7 3
# COOLPAD 9190_T00 3
# 20160829S 3
# HM-NOTE-1S 3
# OWWO Q7 3
# VIVO 1808 3
# VIVO_X21I 3
# OPPO-A77T 3
# MI-5C 3
# T1-701UA 3
# TCL P301M 3
# T2 3
# 1503 A01 3
# SM J3110 3
# VIVO_X510T 3
# G699 3
# PHICOMM E1030 3
# REDMI-NOTE-2 3
# V9S 3
# N1W 3
# CPH1803 3
# C630LW 3
# VIVOY69A 3
# IVVI SS1-03 3
# SM-T321 3
# NX518J 3
# BEST SONNY LT566 3
# VIVO VIVO 1804 3
# HUAWEI GRA TL00 3
# OPPO%20A33 3
# IX21 3
# VIVO%20Y75 3
# PIXEL 3 3
# MI MIX 2 3
# MI4W 3
# KONKA E1 3
# X5L 3
# GT-I9100 3
# 7 PLUS 3
# HTC D816V 3
# DOOV T20L 3
# G2 3
# IVVI V1 3
# WAS-LX1A 3
# VIVO-X20PLUS-A 3
# CHE TL00H 3
# MI-9 3
# VIVO-Y79A 3
# SM-T819C 3
# WELLPHONE 3
# WPOS-3 3
# VIVO VIVO X21UD 3
# CHANGHONGS07 3
# VIVO V1838T 3
# NOAIN M8 3
# SAMSUNG SM-G9600 3
# MIX-3 3
# MI3W 3
# LON-AL00-PD 3
# OPPO_R11_PLUSK 3
# XT1033 3
# VIVONEX 3
# 1503 M02 3
# HUAWEI FLA-AL10 3
# LE+X820 3
# GIONEE-S10 3
# XIAOMI MI PLAY 3
# DUK TL30 3
# HUAWEI C8950D 3
# MEDIAPAD X1 7.0 3
# COOLPAD 8908 3
# EYU T51 3
# REDMI%20NOTE%203 3
# HUAWEI WAS-AL00 3
# REDMI NOTE3双网通 3
# ...
# DOOV 1
# DSL C1 1
# LEPHONE_T9 1
# LENOVO A880 1
# GOME+2017M27A 1
# P00I 1
# N18 1
# DOOV-A8 1
# COOLPAD 8732 1
# U9500 1
# LENOVO+L78031 1
# OUJIA OUJIA2018-S20 1
# SOP-N7 1
# VIVO-Y28L 1
# READBOY_G200 1
# HUAWEI MHA-TL00 1
# OPPO-A79K 1
# COOLPAD%20A8-831 1
# Y23 1
# MEIZUM5 NOTE 1
# XIAOMI__XIAOMI__MIMAX 1
# ZTE-BA520 1
# NOKIA 8.1 1
# C101B 1
# VIVO%201808 1
# 98(M1E7) 1
# XIAOMI__XIAOMI__REDMINOTE4 1
# NOKIA 6.1 1
# MI%20NOTE%202 1
# G0121 1
# ZTE S2004 1
# DOOV+L5M 1
# HUAWEI HONOR V9 1
# HTC S710E 1
# VIVO+X520F 1
# H108 1
# VIVO V1832A 1
# HUAWEI+ALE-CL00 1
# CPU OS 6_0 LIKE MAC OS X) APPLEWEBKIT 1
# LEPHONE-T6+V 1
# 6S PLUS 1
# COOLPAD 5890 1
# VIVO_Y13IL 1
# MLLEDMAX3 1
# MEIZU 16XS 1
# KOOBEE_M6 1
# HTC HTL22 1
# %2522STF-AL00%2522 1
# SCH I939D 1
# SM-N750K 1
# TCL P501M 1
# SC-03J 1
# T1-821W 1
# SUGARY7 1
# U1055 1
# ZTE A2020N2 PRO 1
# CHANGHONG X5 1
# SM-N900P 1
# CM201Z 1
# HUAWEIDIG-AL00 1
# WP_V5 1
# SM-J500N0 1
# H941 1
# LND TL40 1
# LZ6 1
# INFOCUS M310 1
# DOOV_L9 1
# SM-J530S 1
# MLLED N9 1
# ZTE+BA910 1
# MI+PAD 1
# TLP98(M1F3) 1
# VIVO-XPLAY6 1
# HUAWEI T1-701UA 1
# OPPO OPPO A37M 1
# KONKA_510 1
# UOOGOU_T11 1
# VIVO-Y937 1
# DIM 7S 1
# HUAWEI G7-L03 1
# T107 1
# LA-V11 1
# HONOR PRA-AL00 1
# KOPO K33 1
# DOOV_M2 1
# GI-I9500_TMMARS 1
# C880 1
# D1 1
# VIVO%20V3M%20A 1
# SM-G950 1
# BOWAY  T1+ 1
# G3 1
# TETC_H1 1
# HTC DESIRE 820 DUAL SIM 1

# %%
###############################################################################
# 厂商
print(traindata['make'].value_counts())
print('\n')

def deal_make(df, **params):
    """
    处理make
    :param df: 
    :param params: 
    :return: 
    """
    # 转换为小写
    df['make'] = df['make'].apply(lambda x: str(x).lower())
    
    tmp = []
    for index in range(df.shape[0]):
        make = str(df.ix[index, 'make'])
        if make != 'none':
            tmp.append(make)
        else:
            model = str(df.ix[index, 'model'])
            if ' ' in model:
                tmp.append(model.split(' ')[0].lower())
            elif '-' in model:
                tmp.append(model.split('-')[0].lower())
            elif '+' in model:
                tmp.append(model.split('+')[0].lower())
            elif '_' in model:
                tmp.append(model.split('_')[0].lower())
            elif '%' in model:
                tmp.append(model.split('%')[0].lower())                
            else:
                tmp.append(model.lower())
            
    # 替换
    df['make'] = tmp
        
    
    # 中文转英文
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'华为' else x)
    df['make'] = df['make'].apply(lambda x: '360' if x == u'360手机' else x)
    df['make'] = df['make'].apply(lambda x: 'gionee' if x == u'金立' else x)
    df['make'] = df['make'].apply(lambda x: 'samsung' if x == u'三星' else x)
    df['make'] = df['make'].apply(lambda x: 'xiaomi' if x == u'小米' else x)
    df['make'] = df['make'].apply(lambda x: 'honor' if x == u'荣耀' else x)
    df['make'] = df['make'].apply(lambda x: 'meizu' if x == u'魅族' else x)
    df['make'] = df['make'].apply(lambda x: 'coolpad' if x == u'酷派' else x)
    df['make'] = df['make'].apply(lambda x: 'nubia' if x == u'努比亚' else x)
    df['make'] = df['make'].apply(lambda x: '360' if x == u'奇酷' else x)
    df['make'] = df['make'].apply(lambda x: 'oneplus' if x == u'一加' else x)
    df['make'] = df['make'].apply(lambda x: 'zte' if x == u'中兴' else x)
    df['make'] = df['make'].apply(lambda x: 'meitu' if x == u'美图' else x)
    df['make'] = df['make'].apply(lambda x: 'smartisan' if x == u'锤子' else x)
    df['make'] = df['make'].apply(lambda x: 'blephone' if x == u'百立丰' else x)
    df['make'] = df['make'].apply(lambda x: 'xiaolajiao' if x == u'小辣椒' else x)
    df['make'] = df['make'].apply(lambda x: 'cmcc' if x == u'中国移动' else x)
    df['make'] = df['make'].apply(lambda x: 'lenovo' if x == u'联想' else x)
    df['make'] = df['make'].apply(lambda x: 'leeco' if x == u'乐视' else x)
    df['make'] = df['make'].apply(lambda x: 'gree' if x == u'格力' else x)
    df['make'] = df['make'].apply(lambda x: 'motorola' if x == u'摩托罗拉' else x)
    df['make'] = df['make'].apply(lambda x: 'doov' if x == u'朵唯' else x)
    df['make'] = df['make'].apply(lambda x: 'nokia' if x == u'诺基亚' else x)
    df['make'] = df['make'].apply(lambda x: 'hisense' if x == u'海信' else x)
    df['make'] = df['make'].apply(lambda x: 'sony' if x == u'索尼' else x)
    df['make'] = df['make'].apply(lambda x: 'sop' if x == u'赛博宇华' else x)
    df['make'] = df['make'].apply(lambda x: 'fox' if x == u'云狐' else x)
    df['make'] = df['make'].apply(lambda x: 'k-touch' if x == u'天语' else x)
    df['make'] = df['make'].apply(lambda x: 'yusun' if x == u'语信' else x)
    df['make'] = df['make'].apply(lambda x: 'lephone' if x == u'乐丰' else x)
    df['make'] = df['make'].apply(lambda x: 'bbk' if x == u'步步高' else x)
    df['make'] = df['make'].apply(lambda x: 'blackshark' if x == u'黑鲨' else x)
    df['make'] = df['make'].apply(lambda x: 'koobee' if x == u'酷比' else x)
    df['make'] = df['make'].apply(lambda x: 'realme' if x == u'真我' else x)
    
    # 型号  [考虑删除前后对比]
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'eml-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'par-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'honor' if x == u'cor-al10' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'hma-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'clt-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'ine-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'honor' if x == u'jsn-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'lya-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'honor' if x == u'jsn-al00a' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'ane-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'vce-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'honor' if x == u'lld-al20' else x)    
    df['make'] = df['make'].apply(lambda x: 'honor' if x == u'pct-al10' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'ele-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'jkm-al00b' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'jkm-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'dub-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'evr-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'hry-al00a' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'lld-al30' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'clt-al01' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'lya-al10' else x)    
    df['make'] = df['make'].apply(lambda x: 'honor' if x == u'are-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'vog-al10' else x)        
    df['make'] = df['make'].apply(lambda x: 'honor' if x == u'rvl-al09' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'sne-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'honor' if x == u'ane-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'ine-tl00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'vog-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'mar-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'ars-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'cor-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'honor' if x == u'jkm-tl00' else x)    
    df['make'] = df['make'].apply(lambda x: 'honor' if x == u'bkk-al10' else x)    
    df['make'] = df['make'].apply(lambda x: 'honor' if x == u'jsn-tl00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'jkm-al00a' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'hry-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'ane-tl00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'hma-tl00' else x)    
    df['make'] = df['make'].apply(lambda x: 'honor' if x == u'tny-al00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'par-tl00' else x)    
    df['make'] = df['make'].apply(lambda x: 'honor' if x == u'jat-tl00' else x)    
    df['make'] = df['make'].apply(lambda x: 'huawei' if x == u'dut-tl00' else x)     
  

    df['make'] = df['make'].apply(lambda x: 'oppo' if 'pbam00' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'oppo' if 'pbem00' in str(x) else x)  
    df['make'] = df['make'].apply(lambda x: 'oppo' if 'pacm00' in str(x) else x)  
    df['make'] = df['make'].apply(lambda x: 'oppo' if 'pbbm00' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'oppo' if 'paam00' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'oppo' if 'padm00' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'oppo' if 'pact00' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'oppo' if 'pbcm10' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'oppo' if 'pbet00' in str(x) else x)
    
    
    df['make'] = df['make'].apply(lambda x: 'xiaomi' if 'mi' in str(x) else x)
    
    df['make'] = df['make'].apply(lambda x: 'hisense' if 'h==ense' in str(x) else x)
    
    # 判断是否存在
    df['make'] = df['make'].apply(lambda x: 'oppo' if 'oppo' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'vivo' if 'vivo' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'huawei' if 'huawei' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'xiaomi' if 'xiaomi' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'honor' if 'honor' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'meizu' if 'meizu' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'smartisan' if 'smartisan' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'samsung' if 'samsung' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'gionee' if 'gionee' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: '360' if '360' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'oneplus' if 'oneplus' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'nubia' if 'nubia' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'lenovo' if 'lenovo' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'meitu' if 'meitu' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'zte' if 'zte' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'bbk' if 'bbk' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'hisense' if 'hisense' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'coolpad' if 'coolpad' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'generic' if 'generic' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'nokia' if 'nokia' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'lemobile' if 'lemobile' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'letv' if 'letv' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'sony' if 'sony' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'cmcc' if 'cmcc' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'htc' if 'htc' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'xiaolajiao' if 'xiaolajiao' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'blackshark' if 'blackshark' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'blephone' if 'blephone' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'leeco' if 'leeco' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'doov' if 'doov' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'gree' if 'gree' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'gree' if 'geli' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'koobee' if 'koobee' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'motorola' if 'motorola' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'hmd global' if 'hmd global' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'alps' if 'alps' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'k-touch' if 'k-touch' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'yulong' if 'yulong' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'konka' if 'konka' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'rockchip' if 'rockchip' in str(x) else x)    
    df['make'] = df['make'].apply(lambda x: 'sugar' if 'sugar' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'sharp' if 'sharp' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'zuk' if 'zuk' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'gree' if 'geli' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'changhong' if 'changhong' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'lephone' if 'lephone' in str(x) else x)
    df['make'] = df['make'].apply(lambda x: 'tcl' if 'tcl' in str(x) else x)
    
    make = ['oppo', 'vivo', 'huawei', 'xiaomi', 'honor', 'meizu', 'smartisan', 'samsung', 'gionee', '360', 'oneplus', 
            'nubia', 'lenovo', 'meitu','zte', 'bbk', 'hisense', 'coolpad', 'generic', 'nokia', 'lemobile', 
            'letv', 'sony', 'cmcc', 'htc', 'xiaolajiao', 'blackshark', 'blephone', 'leeco', 'doov', 'gree', 'geli', 
            'koobee', 'motorola', 'hmd global', 'alps', 'k-touch', 'yulong', 'konka', 'rockchip', 
            'sugar', 'sharp', 'zuk', 'gree', 'changhong', 'lephone', 'tcl']
    
    df['make'] = df['make'].apply(lambda x: 'none' if str(x) not in make else x)
    
    return df

traindata = deal_make(traindata)
for key, value in traindata['make'].value_counts().items():
    print(key, value)
    
traindata = deal_make(traindata)

for key, value in traindata['make'].value_counts().items():
    print(key, value)

traindata = deal_make(traindata)

for key, value in traindata['make'].value_counts().items():
    print(key, value)
###############################################################################
# Out:
# OPPO                   250359
# vivo                   207547
# HUAWEI                 126195
# Xiaomi                  48005
# HONOR                   45321
#                         ...
# ioutdoor                    1
# hanzhong                    1
# vivo+Y83A                   1
# WAS-TL10                    1
# OPPO,OPPO A37t,A37t         1
# Name: make, Length: 2620, dtype: int64
#
#
# none 634697
# vivo 209119
# xiaomi 65539
# samsung 17828
# huawei 17660
# smartisan 13132
# oppo 11158
# 360 7875
# gionee 6139
# nubia 3790
# meizu 3526
# honor 3013
# coolpad 903
# zte 506
# lephone 492
# oneplus 458
# lenovo 450
# xiaolajiao 416
# blackshark 409
# meitu 319
# cmcc 315
# koobee 280
# motorola 259
# alps 246
# htc 197
# hisense 197
# rockchip 164
# k-touch 158
# leeco 154
# gree 145
# sony 113
# doov 108
# nokia 101
# konka 36
# letv 29
# changhong 26
# bbk 14
# lemobile 11
# sugar 5
# zuk 4
# tcl 3
# sharp 2
# generic 2
# yulong 2
# none 506210
# vivo 209183
# oppo 138284
# xiaomi 65642
# huawei 18191
# samsung 17842
# smartisan 13132
# 360 7896
# gionee 6177
# nubia 3790
# meizu 3551
# honor 3234
# coolpad 912
# oneplus 581
# zte 528
# lephone 492
# lenovo 460
# xiaolajiao 416
# blackshark 409
# meitu 322
# cmcc 316
# koobee 280
# motorola 259
# alps 246
# htc 236
# hisense 200
# rockchip 164
# k-touch 158
# leeco 154
# gree 145
# nokia 117
# sony 114
# doov 110
# changhong 97
# letv 57
# konka 42
# bbk 14
# lemobile 12
# zuk 11
# sugar 7
# tcl 3
# sharp 2
# generic 2
# yulong 2
# none 506210
# vivo 209183
# oppo 138284
# xiaomi 65642
# huawei 18191
# samsung 17842
# smartisan 13132
# 360 7896
# gionee 6177
# nubia 3790
# meizu 3551
# honor 3234
# coolpad 912
# oneplus 581
# zte 528
# lephone 492
# lenovo 460
# xiaolajiao 416
# blackshark 409
# meitu 322
# cmcc 316
# koobee 280
# motorola 259
# alps 246
# htc 236
# hisense 200
# rockchip 164
# k-touch 158
# leeco 154
# gree 145
# nokia 117
# sony 114
# doov 110
# changhong 97
# letv 57
# konka 42
# bbk 14
# lemobile 12
# zuk 11
# sugar 7
# tcl 3
# sharp 2
# generic 2
# yulong 2
# /home/wjunneng/Python/anaconda3/envs/lightgbm/lib/python3.6/site-packages/ipykernel_launcher.py:15: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   from ipykernel import kernelapp as app
# /home/wjunneng/Python/anaconda3/envs/lightgbm/lib/python3.6/site-packages/ipykernel_launcher.py:19: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated

# %%
###############################################################################
# 网络类型 0-未知, 1-有线网, 2-WIFI, 3-蜂窝网络未知, 4-2G, 5-3G, 6–4G
# 构造特征： 0-未知/1-有线网络/2-无线网络
print(traindata['ntt'].value_counts())
print('\n')

print(testdata_feature['ntt'].value_counts())
print('\n')

def deal_ntt(df, **params):
    """
    处理ntt
    :param df: 
    :param params: 
    :return: 
    """
    df['ntt'] = df['ntt'].apply(lambda x: str(x))
    df['ntt_type'] = df['ntt'].apply(lambda x: str(2) if int(float(x)) in [2, 3, 4, 5, 6, 7] else x)
    
    return df

traindata = deal_ntt(traindata)
testdata_feature = deal_ntt(testdata_feature)

print(traindata['ntt'].value_counts())
print('\n')

print(testdata_feature['ntt'].value_counts())
print('\n')

print(traindata['ntt_type'].value_counts())
print('\n')

print(testdata_feature['ntt_type'].value_counts())
print('\n')
###############################################################################

# %%
###############################################################################
# 运营商 0-未知, 46000-移动, 46001-联通, 46003-电信 【-1-中国广电？46002/46005/46006/46007...】
print(traindata['carrier'].value_counts())
print('\n')

print(testdata_feature['carrier'].value_counts())
print('\n')

def deal_carrier(df, **params):
    """
    处理运营商
    :param df: 
    :param params: 
    :return: 
    """
    df['carrier'] = df['carrier'].apply(lambda x: str(1) if int(x) == 0 else x)
    df['carrier'] = df['carrier'].apply(lambda x: str(2) if int(x) == 46000 else x)
    df['carrier'] = df['carrier'].apply(lambda x: str(3) if int(x) == 46001 else x)
    df['carrier'] = df['carrier'].apply(lambda x: str(4) if int(x) == 46003 else x)
    df['carrier'] = df['carrier'].apply(lambda x: str(5) if str(x) not in [str(1), str(2), str(3), str(4)] else x)
    
    return df
    
traindata = deal_carrier(traindata)
testdata_feature = deal_carrier(testdata_feature)
    
# 运营商 0-未知, 46000-移动, 46001-联通, 46003-电信 【-1-中国广电？】
print(traindata['carrier'].value_counts())
print('\n')

print(testdata_feature['carrier'].value_counts())
print('\n')
###############################################################################

# %%
###############################################################################
# 操作系统 : Android, iOS
print(traindata['os'].unique())
print('\n')

# 操作系统 
print(testdata_feature['os'].unique())
print('\n')

def deal_os(df, **params):
    """
    处理操作系统
    :param df: 
    :param params: 
    :return: 
    """
    if 'os' in df.columns:
        # 先将所有值转化为小写
        df['os'] = df['os'].apply(lambda x: x.lower())
        # 如果所有值都相同，则剔除
        if len(set(df['os'])) is 1:
            del df['os']
    
    return df
    
traindata = deal_os(traindata)

# 操作系统
print(traindata.columns)
print('\n')

testdata_feature = deal_os(testdata_feature)

# 操作系统
print(testdata_feature.columns)
print('\n')
###############################################################################

# %%
# 操作系统版本
print(traindata['osv'].value_counts())
print('\n')

# %%
###############################################################################
# 横竖屏:0竖屏，1横屏
print(traindata['orientation'].unique())
print('\n')

# 横竖屏:0竖屏，1横屏
print(testdata_feature['orientation'].unique())
print('\n')

# train 中orientation为90的仅有一条数据为0，其余结为1 

# (1, 28)
train_2 = traindata[traindata.orientation.astype(int) == 2]
print(train_2.shape)
# (0, 27)
test_2 = testdata_feature[traindata.orientation.astype(int) == 2] 
print(test_2.shape)
# (110, 28)
train_90 = traindata[traindata.orientation.astype(int) == 90] 
print(train_90.shape)
# (15, 27)
test_90 = testdata_feature[traindata.orientation.astype(int) == 90] 
print(test_90.shape)

def deal_orientation(df, **params):
    """
    剔除非0和1的数据 【即非横/竖屏的数据】
    :param df: 
    :param params: 
    :return: 
    """
    df = df[(df['orientation'].astype(int) == 0) | (df['orientation'].astype(int) == 1) | (df['orientation'].astype(int) == 90)]
    
    return df

traindata = deal_orientation(traindata)
testdata_feature = deal_orientation(testdata_feature)

# 横竖屏:0竖屏，1横屏
print(traindata['orientation'].unique())
print('\n')

# 横竖屏:0竖屏，1横屏
print(testdata_feature['orientation'].unique())
print('\n')
###############################################################################

# %%
###############################################################################
# 语言
print(traindata['lan'].value_counts())
print('\n')

print(testdata_feature['lan'].value_counts())
print('\n')

# print(traindata[traindata['lan'] == 'en'][['label', 'province', 'city']])

def deal_lan(df, **params):
    """
    处理语言
    :param df: 
    :param params: 
    :return: 
    """
    df['lan'] = df['lan'].fillna(0)
    
    df['lan'] = df['lan'].apply(lambda x: str(x).lower())
    # 优先处理cn: 1
    df['lan'] = df['lan'].apply(lambda x: '1' if 'cn' in str(x) else x)
    # 处理tw： 2
    df['lan'] = df['lan'].apply(lambda x: '2' if 'tw' in str(x) else x)
    # 处理hk: 2
    df['lan'] = df['lan'].apply(lambda x: '2' if 'hk' in str(x) else x)
    # 处理en: 3
    df['lan'] = df['lan'].apply(lambda x: '3' if 'en' in str(x) else x)
    # 处理zh: 1
    df['lan'] = df['lan'].apply(lambda x: '1' if 'zh' in str(x) else x)
    # 其他： 4
    df['lan'] = df['lan'].apply(lambda x: '4' if not x in ['0', '1', '2', '3'] else x)
    
    return df

# 处理语言
traindata = deal_lan(traindata)
testdata_feature = testdata_feature(testdata_feature)

print(traindata['lan'].value_counts())
print('\n')

print(testdata_feature['lan'].value_counts())
print('\n')
###############################################################################

# %%
###############################################################################
# 设备高
print(traindata['h'].value_counts())
print('\n')

# 设备宽
print(traindata['w'].value_counts())
print('\n')

# 屏幕密度
print(traindata['ppi'].value_counts())
print('\n')


def deal_h_w_ppi(df, fillna_type, **params):
    """
    处理宽高/密度
    :param df: 
    :param params: 
    :return: 
    """
    import numpy as np
    
    if fillna_type is 'mean':
        # 利用均值填充
        df['h'].replace(0, df['h'].mean(), inplace=True)
        df['w'].replace(0, df['w'].mean(), inplace=True)
        df['ppi'].replace(0, df['ppi'].mean(), inplace=True)
    
    elif fillna_type is 'median':
        # 利用均值填充
        df['h'].replace(0, df['h'].median(), inplace=True)
        df['w'].replace(0, df['w'].median(), inplace=True)
        df['ppi'].replace(0, df['ppi'].median(), inplace=True)
        
    else:
        # 利用众数填充
        df['h'].replace(0, df['h'].mode().max(), inplace=True)
        df['w'].replace(0, df['w'].mode().max(), inplace=True)
        df['ppi'].replace(0, df['ppi'].mode().max(), inplace=True)
    
    # 添加面积列
    df['area'] = df['h'] * df['w']
    
    # 添加宽高列
    df['aspect_ratio'] = df['h'] / df['w']
    
    # 归一化函数
    max_min_scaler = lambda x : (x-np.min(x))/(np.max(x)-np.min(x))

    df['h'] = df[['h']].apply(max_min_scaler)
    df['w'] = df[['w']].apply(max_min_scaler)
    df['ppi'] = df[['ppi']].apply(max_min_scaler)
    
    return df

traindata = deal_h_w_ppi(traindata, 'mean')
testdata_feature = deal_h_w_ppi(testdata_feature, 'mean')


# 设备高
print(traindata['h'].value_counts())
print('\n')

# 设备宽
print(traindata['w'].value_counts())
print('\n')

# 屏幕密度
print(traindata['ppi'].value_counts())
print('\n')
###############################################################################
